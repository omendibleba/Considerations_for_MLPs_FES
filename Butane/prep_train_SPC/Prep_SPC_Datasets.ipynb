# %% [markdown]
# #### This notebook presents a tutorial on how to select the configurations previously generated using Classical molecular dynamics (CLMD) and used as initial configurations for single point ab initi calculations using CP2K.
#
# Important files in this directory include:
# - <font color='yellow'>"BASIS_MOLOPT", "dftd3.dat", "GTH_POTENTIALS", "HFX_BASIS"</font> --> Basis sets and pseudo-potentials reqired by CP2K to describe interactions
# - <font color='yellow'>"traj_0.inp"</font> --> Reference CP2K input file for single point calculations
# - <font color='yellow'>"prep_spc_from_npz.py"</font> --> Script to generate folders with required files to run single point calculation using CP2K
# - <font color='yellow'>"spc_results_to_npz"</font> --> Script to parse output from calculations and generate SPC training dataset.

# %%
# imports 
import os 

## Define number of samples to be selected
num_samples = 500

# %%
# Define path to the Boltzmann Distribution training data set. 

Butane_BoltzDist_CLC_path = './../prep_train_CLC/CLC_dataset_preparation/BoltzmannDist_500Frames_CLC.npz'
name = 'But_BoltzDist_SPC'
# ##Run the prep_spc_from_npz script to genrerate folders containing the required data to run the SPCs using CP2K
# os.system(f'python prep_spc_from_npz.py --input {Butane_BoltzDist_CLC_path} --samples {int(num_samples)} --name {name}')

# Define path to Uniform Distribution training data set
Butane_UnivDist_CLC_path = './../prep_train_CLC/CLC_dataset_preparation/./UniformDist_500Frames_CLC.npz'
name = 'But_UnivDist_SPC'
# ##Run the prep_spc_from_npz script to genrerate folders containing the required data to run the SPCs using CP2K
# os.system(f'python prep_spc_from_npz.py --input {Butane_UnivDist_CLC_path} --samples {int(num_samples)} --name {name}')


# Define path to Half Left Uniform Distribution training data set
Butane_HL_UnivDist_CLC_path = './../prep_train_CLC/CLC_dataset_preparation/./HalfLeft_UniformDist_500Frames_CLC.npz'
name = 'But_HL_UnivDist_SPC'
# ##Run the prep_spc_from_npz script to genrerate folders containing the required data to run the SPCs using CP2K
# os.system(f'python prep_spc_from_npz.py --input {Butane_HL_UnivDist_CLC_path} --samples {int(num_samples)} --name {name}')


# Define path to Half Left Uniform Distribution training data set
Butane_HR_UnivDist_CLC_path = './../prep_train_CLC/CLC_dataset_preparation/./HalfRight_UniformDist_500Frames_CLC.npz'
name = 'But_HR_UnivDist_SPC'
# ##Run the prep_spc_from_npz script to genrerate folders containing the required data to run the SPCs using CP2K
# os.system(f'python prep_spc_from_npz.py --input {Butane_HR_UnivDist_CLC_path} --samples {int(num_samples)} --name {name}')


# Define path to Bias Left Distribution training data set
Butane_Left_BiasDist_CLC_path = './../prep_train_CLC/CLC_dataset_preparation/./BiasLeftDist_500Frames_CLC.npz'
name = 'But_Left_BiasDist_SPC'
# ##Run the prep_spc_from_npz script to genrerate folders containing the required data to run the SPCs using CP2K
# os.system(f'python prep_spc_from_npz.py --input {Butane_Left_BiasDist_CLC_path} --samples {int(num_samples)} --name {name}')

# Define path to Bias Right Distribution training data set
Butane_Right_BiasDist_CLC_path = './../prep_train_CLC/CLC_dataset_preparation/./BiasRightDist_500Frames_CLC.npz'
name = 'But_Right_BiasDist_SPC'
# ##Run the prep_spc_from_npz script to genrerate folders containing the required data to run the SPCs using CP2K
# os.system(f'python prep_spc_from_npz.py --input {Butane_Right_BiasDist_CLC_path} --samples {int(num_samples)} --name {name}')

# Define path to Bias Left Half Distribution training data set
Butane_LeftHalf_BiasDist_CLC_path = './../prep_train_CLC/CLC_dataset_preparation/./BiasRight_HalftDist_500Frames_CLC.npz'
name = 'But_LeftHalf_BiasDist_SPC'
# ##Run the prep_spc_from_npz script to genrerate folders containing the required data to run the SPCs using CP2K
# os.system(f'python prep_spc_from_npz.py --input {Butane_LeftHalf_BiasDist_CLC_path} --samples {int(num_samples)} --name {name}')

# Define path to Bias LeftRight Half Distribution training data set
Butane_RightHalf_BiasDist_CLC_path = './../prep_train_CLC/CLC_dataset_preparation/./BiasRight_HalftDist_500Frames_CLC.npz'
name = 'But_RightHalf_BiasDist_SPC'
# ##Run the prep_spc_from_npz script to genrerate folders containing the required data to run the SPCs using CP2K
# os.system(f'python prep_spc_from_npz.py --input {Butane_RightHalf_BiasDist_CLC_path} --samples {int(num_samples)} --name {name}')
# Out:
# Create folders for single point calculations.
#
#
# Reading Files...
#
# The files in this npz file are:
#
# ['R', 'F', 'E', 'z', 'diheds']
#
#
#
# Shape of arrays:
#
# Coordinates:  (500, 14, 3)
# Energies:  (500,)
# Forces:  (500, 14, 3)
# Types:  (14,)
#
# Array of types:
#
# [6 1 1 1 6 1 1 6 1 1 6 1 1 1]
#
#
#
# Original array of types:
#
# ['C', 'H', 'H', 'H', 'C', 'H', 'H', 'C', 'H', 'H', 'C', 'H', 'H', 'H']
#
#
#
# Modified array of types:
#
# ['C', 'H', 'H', 'H', 'C', 'H', 'H', 'C', 'H', 'H', 'C', 'H', 'H', 'H']
#
#
# Creating input 1 of 500
#
# Found file: But_BoltzDist_SPC_1.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_1
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_1.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_1/But_BoltzDist_SPC_1.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_1'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_1'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_1'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_1'.
# Soft links created for But_BoltzDist_SPC_1
#
#
# Creating input 2 of 500
#
# Found file: But_BoltzDist_SPC_2.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_2
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_2.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_2/But_BoltzDist_SPC_2.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_2'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_2'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_2'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_2'.
# Soft links created for But_BoltzDist_SPC_2
#
#
# Creating input 3 of 500
#
# Found file: But_BoltzDist_SPC_3.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_3
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_3.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_3/But_BoltzDist_SPC_3.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_3'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_3'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_3'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_3'.
# Soft links created for But_BoltzDist_SPC_3
#
#
# Creating input 4 of 500
#
# Found file: But_BoltzDist_SPC_4.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_4
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_4.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_4/But_BoltzDist_SPC_4.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_4'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_4'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_4'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_4'.
# Soft links created for But_BoltzDist_SPC_4
#
#
# Creating input 5 of 500
#
# Found file: But_BoltzDist_SPC_5.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_5
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_5.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_5/But_BoltzDist_SPC_5.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_5'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_5'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_5'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_5'.
# Soft links created for But_BoltzDist_SPC_5
#
#
# Creating input 6 of 500
#
# Found file: But_BoltzDist_SPC_6.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_6
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_6.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_6/But_BoltzDist_SPC_6.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_6'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_6'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_6'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_6'.
# Soft links created for But_BoltzDist_SPC_6
#
#
# Creating input 7 of 500
#
# Found file: But_BoltzDist_SPC_7.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_7
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_7.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_7/But_BoltzDist_SPC_7.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_7'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_7'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_7'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_7'.
# Soft links created for But_BoltzDist_SPC_7
#
#
# Creating input 8 of 500
#
# Found file: But_BoltzDist_SPC_8.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_8
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_8.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_8/But_BoltzDist_SPC_8.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_8'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_8'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_8'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_8'.
# Soft links created for But_BoltzDist_SPC_8
#
#
# Creating input 9 of 500
#
# Found file: But_BoltzDist_SPC_9.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_9
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_9.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_9/But_BoltzDist_SPC_9.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_9'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_9'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_9'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_9'.
# Soft links created for But_BoltzDist_SPC_9
#
#
# Creating input 10 of 500
#
# Found file: But_BoltzDist_SPC_10.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_10
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_10.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_10/But_BoltzDist_SPC_10.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_10'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_10'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_10'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_10'.
# Soft links created for But_BoltzDist_SPC_10
#
#
# Creating input 11 of 500
#
# Found file: But_BoltzDist_SPC_11.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_11
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_11.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_11/But_BoltzDist_SPC_11.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_11'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_11'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_11'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_11'.
# Soft links created for But_BoltzDist_SPC_11
#
#
# Creating input 12 of 500
#
# Found file: But_BoltzDist_SPC_12.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_12
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_12.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_12/But_BoltzDist_SPC_12.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_12'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_12'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_12'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_12'.
# Soft links created for But_BoltzDist_SPC_12
#
#
# Creating input 13 of 500
#
# Found file: But_BoltzDist_SPC_13.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_13
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_13.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_13/But_BoltzDist_SPC_13.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_13'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_13'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_13'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_13'.
# Soft links created for But_BoltzDist_SPC_13
#
#
# Creating input 14 of 500
#
# Found file: But_BoltzDist_SPC_14.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_14
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_14.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_14/But_BoltzDist_SPC_14.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_14'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_14'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_14'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_14'.
# Soft links created for But_BoltzDist_SPC_14
#
#
# Creating input 15 of 500
#
# Found file: But_BoltzDist_SPC_15.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_15
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_15.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_15/But_BoltzDist_SPC_15.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_15'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_15'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_15'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_15'.
# Soft links created for But_BoltzDist_SPC_15
#
#
# Creating input 16 of 500
#
# Found file: But_BoltzDist_SPC_16.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_16
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_16.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_16/But_BoltzDist_SPC_16.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_16'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_16'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_16'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_16'.
# Soft links created for But_BoltzDist_SPC_16
#
#
# Creating input 17 of 500
#
# Found file: But_BoltzDist_SPC_17.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_17
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_17.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_17/But_BoltzDist_SPC_17.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_17'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_17'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_17'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_17'.
# Soft links created for But_BoltzDist_SPC_17
#
#
# Creating input 18 of 500
#
# Found file: But_BoltzDist_SPC_18.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_18
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_18.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_18/But_BoltzDist_SPC_18.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_18'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_18'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_18'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_18'.
# Soft links created for But_BoltzDist_SPC_18
#
#
# Creating input 19 of 500
#
# Found file: But_BoltzDist_SPC_19.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_19
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_19.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_19/But_BoltzDist_SPC_19.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_19'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_19'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_19'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_19'.
# Soft links created for But_BoltzDist_SPC_19
#
#
# Creating input 20 of 500
#
# Found file: But_BoltzDist_SPC_20.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_20
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_20.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_20/But_BoltzDist_SPC_20.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_20'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_20'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_20'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_20'.
# Soft links created for But_BoltzDist_SPC_20
#
#
# Creating input 21 of 500
#
# Found file: But_BoltzDist_SPC_21.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_21
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_21.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_21/But_BoltzDist_SPC_21.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_21'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_21'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_21'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_21'.
# Soft links created for But_BoltzDist_SPC_21
#
#
# Creating input 22 of 500
#
# Found file: But_BoltzDist_SPC_22.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_22
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_22.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_22/But_BoltzDist_SPC_22.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_22'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_22'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_22'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_22'.
# Soft links created for But_BoltzDist_SPC_22
#
#
# Creating input 23 of 500
#
# Found file: But_BoltzDist_SPC_23.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_23
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_23.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_23/But_BoltzDist_SPC_23.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_23'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_23'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_23'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_23'.
# Soft links created for But_BoltzDist_SPC_23
#
#
# Creating input 24 of 500
#
# Found file: But_BoltzDist_SPC_24.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_24
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_24.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_24/But_BoltzDist_SPC_24.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_24'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_24'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_24'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_24'.
# Soft links created for But_BoltzDist_SPC_24
#
#
# Creating input 25 of 500
#
# Found file: But_BoltzDist_SPC_25.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_25
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_25.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_25/But_BoltzDist_SPC_25.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_25'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_25'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_25'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_25'.
# Soft links created for But_BoltzDist_SPC_25
#
#
# Creating input 26 of 500
#
# Found file: But_BoltzDist_SPC_26.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_26
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_26.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_26/But_BoltzDist_SPC_26.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_26'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_26'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_26'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_26'.
# Soft links created for But_BoltzDist_SPC_26
#
#
# Creating input 27 of 500
#
# Found file: But_BoltzDist_SPC_27.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_27
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_27.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_27/But_BoltzDist_SPC_27.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_27'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_27'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_27'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_27'.
# Soft links created for But_BoltzDist_SPC_27
#
#
# Creating input 28 of 500
#
# Found file: But_BoltzDist_SPC_28.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_28
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_28.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_28/But_BoltzDist_SPC_28.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_28'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_28'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_28'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_28'.
# Soft links created for But_BoltzDist_SPC_28
#
#
# Creating input 29 of 500
#
# Found file: But_BoltzDist_SPC_29.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_29
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_29.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_29/But_BoltzDist_SPC_29.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_29'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_29'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_29'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_29'.
# Soft links created for But_BoltzDist_SPC_29
#
#
# Creating input 30 of 500
#
# Found file: But_BoltzDist_SPC_30.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_30
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_30.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_30/But_BoltzDist_SPC_30.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_30'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_30'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_30'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_30'.
# Soft links created for But_BoltzDist_SPC_30
#
#
# Creating input 31 of 500
#
# Found file: But_BoltzDist_SPC_31.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_31
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_31.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_31/But_BoltzDist_SPC_31.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_31'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_31'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_31'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_31'.
# Soft links created for But_BoltzDist_SPC_31
#
#
# Creating input 32 of 500
#
# Found file: But_BoltzDist_SPC_32.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_32
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_32.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_32/But_BoltzDist_SPC_32.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_32'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_32'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_32'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_32'.
# Soft links created for But_BoltzDist_SPC_32
#
#
# Creating input 33 of 500
#
# Found file: But_BoltzDist_SPC_33.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_33
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_33.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_33/But_BoltzDist_SPC_33.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_33'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_33'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_33'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_33'.
# Soft links created for But_BoltzDist_SPC_33
#
#
# Creating input 34 of 500
#
# Found file: But_BoltzDist_SPC_34.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_34
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_34.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_34/But_BoltzDist_SPC_34.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_34'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_34'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_34'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_34'.
# Soft links created for But_BoltzDist_SPC_34
#
#
# Creating input 35 of 500
#
# Found file: But_BoltzDist_SPC_35.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_35
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_35.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_35/But_BoltzDist_SPC_35.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_35'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_35'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_35'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_35'.
# Soft links created for But_BoltzDist_SPC_35
#
#
# Creating input 36 of 500
#
# Found file: But_BoltzDist_SPC_36.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_36
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_36.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_36/But_BoltzDist_SPC_36.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_36'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_36'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_36'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_36'.
# Soft links created for But_BoltzDist_SPC_36
#
#
# Creating input 37 of 500
#
# Found file: But_BoltzDist_SPC_37.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_37
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_37.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_37/But_BoltzDist_SPC_37.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_37'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_37'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_37'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_37'.
# Soft links created for But_BoltzDist_SPC_37
#
#
# Creating input 38 of 500
#
# Found file: But_BoltzDist_SPC_38.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_38
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_38.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_38/But_BoltzDist_SPC_38.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_38'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_38'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_38'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_38'.
# Soft links created for But_BoltzDist_SPC_38
#
#
# Creating input 39 of 500
#
# Found file: But_BoltzDist_SPC_39.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_39
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_39.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_39/But_BoltzDist_SPC_39.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_39'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_39'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_39'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_39'.
# Soft links created for But_BoltzDist_SPC_39
#
#
# Creating input 40 of 500
#
# Found file: But_BoltzDist_SPC_40.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_40
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_40.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_40/But_BoltzDist_SPC_40.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_40'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_40'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_40'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_40'.
# Soft links created for But_BoltzDist_SPC_40
#
#
# Creating input 41 of 500
#
# Found file: But_BoltzDist_SPC_41.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_41
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_41.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_41/But_BoltzDist_SPC_41.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_41'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_41'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_41'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_41'.
# Soft links created for But_BoltzDist_SPC_41
#
#
# Creating input 42 of 500
#
# Found file: But_BoltzDist_SPC_42.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_42
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_42.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_42/But_BoltzDist_SPC_42.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_42'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_42'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_42'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_42'.
# Soft links created for But_BoltzDist_SPC_42
#
#
# Creating input 43 of 500
#
# Found file: But_BoltzDist_SPC_43.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_43
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_43.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_43/But_BoltzDist_SPC_43.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_43'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_43'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_43'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_43'.
# Soft links created for But_BoltzDist_SPC_43
#
#
# Creating input 44 of 500
#
# Found file: But_BoltzDist_SPC_44.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_44
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_44.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_44/But_BoltzDist_SPC_44.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_44'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_44'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_44'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_44'.
# Soft links created for But_BoltzDist_SPC_44
#
#
# Creating input 45 of 500
#
# Found file: But_BoltzDist_SPC_45.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_45
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_45.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_45/But_BoltzDist_SPC_45.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_45'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_45'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_45'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_45'.
# Soft links created for But_BoltzDist_SPC_45
#
#
# Creating input 46 of 500
#
# Found file: But_BoltzDist_SPC_46.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_46
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_46.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_46/But_BoltzDist_SPC_46.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_46'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_46'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_46'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_46'.
# Soft links created for But_BoltzDist_SPC_46
#
#
# Creating input 47 of 500
#
# Found file: But_BoltzDist_SPC_47.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_47
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_47.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_47/But_BoltzDist_SPC_47.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_47'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_47'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_47'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_47'.
# Soft links created for But_BoltzDist_SPC_47
#
#
# Creating input 48 of 500
#
# Found file: But_BoltzDist_SPC_48.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_48
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_48.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_48/But_BoltzDist_SPC_48.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_48'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_48'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_48'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_48'.
# Soft links created for But_BoltzDist_SPC_48
#
#
# Creating input 49 of 500
#
# Found file: But_BoltzDist_SPC_49.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_49
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_49.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_49/But_BoltzDist_SPC_49.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_49'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_49'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_49'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_49'.
# Soft links created for But_BoltzDist_SPC_49
#
#
# Creating input 50 of 500
#
# Found file: But_BoltzDist_SPC_50.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_50
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_50.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_50/But_BoltzDist_SPC_50.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_50'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_50'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_50'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_50'.
# Soft links created for But_BoltzDist_SPC_50
#
#
# Creating input 51 of 500
#
# Found file: But_BoltzDist_SPC_51.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_51
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_51.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_51/But_BoltzDist_SPC_51.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_51'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_51'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_51'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_51'.
# Soft links created for But_BoltzDist_SPC_51
#
#
# Creating input 52 of 500
#
# Found file: But_BoltzDist_SPC_52.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_52
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_52.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_52/But_BoltzDist_SPC_52.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_52'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_52'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_52'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_52'.
# Soft links created for But_BoltzDist_SPC_52
#
#
# Creating input 53 of 500
#
# Found file: But_BoltzDist_SPC_53.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_53
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_53.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_53/But_BoltzDist_SPC_53.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_53'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_53'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_53'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_53'.
# Soft links created for But_BoltzDist_SPC_53
#
#
# Creating input 54 of 500
#
# Found file: But_BoltzDist_SPC_54.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_54
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_54.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_54/But_BoltzDist_SPC_54.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_54'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_54'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_54'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_54'.
# Soft links created for But_BoltzDist_SPC_54
#
#
# Creating input 55 of 500
#
# Found file: But_BoltzDist_SPC_55.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_55
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_55.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_55/But_BoltzDist_SPC_55.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_55'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_55'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_55'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_55'.
# Soft links created for But_BoltzDist_SPC_55
#
#
# Creating input 56 of 500
#
# Found file: But_BoltzDist_SPC_56.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_56
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_56.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_56/But_BoltzDist_SPC_56.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_56'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_56'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_56'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_56'.
# Soft links created for But_BoltzDist_SPC_56
#
#
# Creating input 57 of 500
#
# Found file: But_BoltzDist_SPC_57.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_57
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_57.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_57/But_BoltzDist_SPC_57.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_57'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_57'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_57'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_57'.
# Soft links created for But_BoltzDist_SPC_57
#
#
# Creating input 58 of 500
#
# Found file: But_BoltzDist_SPC_58.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_58
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_58.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_58/But_BoltzDist_SPC_58.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_58'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_58'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_58'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_58'.
# Soft links created for But_BoltzDist_SPC_58
#
#
# Creating input 59 of 500
#
# Found file: But_BoltzDist_SPC_59.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_59
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_59.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_59/But_BoltzDist_SPC_59.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_59'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_59'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_59'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_59'.
# Soft links created for But_BoltzDist_SPC_59
#
#
# Creating input 60 of 500
#
# Found file: But_BoltzDist_SPC_60.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_60
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_60.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_60/But_BoltzDist_SPC_60.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_60'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_60'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_60'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_60'.
# Soft links created for But_BoltzDist_SPC_60
#
#
# Creating input 61 of 500
#
# Found file: But_BoltzDist_SPC_61.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_61
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_61.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_61/But_BoltzDist_SPC_61.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_61'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_61'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_61'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_61'.
# Soft links created for But_BoltzDist_SPC_61
#
#
# Creating input 62 of 500
#
# Found file: But_BoltzDist_SPC_62.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_62
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_62.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_62/But_BoltzDist_SPC_62.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_62'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_62'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_62'.
# ...
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_480'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_480'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_480'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_480'.
# Soft links created for But_BoltzDist_SPC_480
#
#
# Creating input 481 of 500
#
# Found file: But_BoltzDist_SPC_481.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_481
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_481.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_481/But_BoltzDist_SPC_481.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_481'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_481'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_481'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_481'.
# Soft links created for But_BoltzDist_SPC_481
#
#
# Creating input 482 of 500
#
# Found file: But_BoltzDist_SPC_482.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_482
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_482.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_482/But_BoltzDist_SPC_482.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_482'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_482'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_482'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_482'.
# Soft links created for But_BoltzDist_SPC_482
#
#
# Creating input 483 of 500
#
# Found file: But_BoltzDist_SPC_483.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_483
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_483.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_483/But_BoltzDist_SPC_483.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_483'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_483'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_483'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_483'.
# Soft links created for But_BoltzDist_SPC_483
#
#
# Creating input 484 of 500
#
# Found file: But_BoltzDist_SPC_484.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_484
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_484.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_484/But_BoltzDist_SPC_484.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_484'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_484'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_484'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_484'.
# Soft links created for But_BoltzDist_SPC_484
#
#
# Creating input 485 of 500
#
# Found file: But_BoltzDist_SPC_485.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_485
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_485.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_485/But_BoltzDist_SPC_485.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_485'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_485'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_485'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_485'.
# Soft links created for But_BoltzDist_SPC_485
#
#
# Creating input 486 of 500
#
# Found file: But_BoltzDist_SPC_486.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_486
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_486.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_486/But_BoltzDist_SPC_486.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_486'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_486'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_486'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_486'.
# Soft links created for But_BoltzDist_SPC_486
#
#
# Creating input 487 of 500
#
# Found file: But_BoltzDist_SPC_487.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_487
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_487.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_487/But_BoltzDist_SPC_487.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_487'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_487'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_487'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_487'.
# Soft links created for But_BoltzDist_SPC_487
#
#
# Creating input 488 of 500
#
# Found file: But_BoltzDist_SPC_488.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_488
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_488.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_488/But_BoltzDist_SPC_488.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_488'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_488'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_488'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_488'.
# Soft links created for But_BoltzDist_SPC_488
#
#
# Creating input 489 of 500
#
# Found file: But_BoltzDist_SPC_489.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_489
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_489.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_489/But_BoltzDist_SPC_489.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_489'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_489'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_489'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_489'.
# Soft links created for But_BoltzDist_SPC_489
#
#
# Creating input 490 of 500
#
# Found file: But_BoltzDist_SPC_490.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_490
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_490.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_490/But_BoltzDist_SPC_490.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_490'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_490'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_490'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_490'.
# Soft links created for But_BoltzDist_SPC_490
#
#
# Creating input 491 of 500
#
# Found file: But_BoltzDist_SPC_491.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_491
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_491.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_491/But_BoltzDist_SPC_491.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_491'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_491'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_491'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_491'.
# Soft links created for But_BoltzDist_SPC_491
#
#
# Creating input 492 of 500
#
# Found file: But_BoltzDist_SPC_492.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_492
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_492.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_492/But_BoltzDist_SPC_492.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_492'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_492'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_492'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_492'.
# Soft links created for But_BoltzDist_SPC_492
#
#
# Creating input 493 of 500
#
# Found file: But_BoltzDist_SPC_493.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_493
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_493.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_493/But_BoltzDist_SPC_493.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_493'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_493'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_493'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_493'.
# Soft links created for But_BoltzDist_SPC_493
#
#
# Creating input 494 of 500
#
# Found file: But_BoltzDist_SPC_494.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_494
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_494.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_494/But_BoltzDist_SPC_494.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_494'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_494'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_494'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_494'.
# Soft links created for But_BoltzDist_SPC_494
#
#
# Creating input 495 of 500
#
# Found file: But_BoltzDist_SPC_495.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_495
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_495.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_495/But_BoltzDist_SPC_495.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_495'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_495'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_495'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_495'.
# Soft links created for But_BoltzDist_SPC_495
#
#
# Creating input 496 of 500
#
# Found file: But_BoltzDist_SPC_496.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_496
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_496.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_496/But_BoltzDist_SPC_496.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_496'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_496'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_496'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_496'.
# Soft links created for But_BoltzDist_SPC_496
#
#
# Creating input 497 of 500
#
# Found file: But_BoltzDist_SPC_497.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_497
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_497.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_497/But_BoltzDist_SPC_497.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_497'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_497'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_497'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_497'.
# Soft links created for But_BoltzDist_SPC_497
#
#
# Creating input 498 of 500
#
# Found file: But_BoltzDist_SPC_498.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_498
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_498.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_498/But_BoltzDist_SPC_498.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_498'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_498'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_498'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_498'.
# Soft links created for But_BoltzDist_SPC_498
#
#
# Creating input 499 of 500
#
# Found file: But_BoltzDist_SPC_499.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_499
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_499.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_499/But_BoltzDist_SPC_499.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_499'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_499'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_499'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_499'.
# Soft links created for But_BoltzDist_SPC_499
#
#
# Creating input 500 of 500
#
# Found file: But_BoltzDist_SPC_500.xyz
# Creating new folder: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_500
# Moving file: /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_500.xyz to /media/nando/New_Volume/Phase_2/NNFFs_V3/Deliverables/Butane/prep_train_SPC/But_BoltzDist_SPC_500/But_BoltzDist_SPC_500.xyz
# Files moved into separate folders.
# Symbolic link created for 'BASIS_MOLOPT' in 'But_BoltzDist_SPC_500'.
# Symbolic link created for 'dftd3.dat' in 'But_BoltzDist_SPC_500'.
# Symbolic link created for 'GTH_POTENTIALS' in 'But_BoltzDist_SPC_500'.
# Symbolic link created for 'HFX_BASIS' in 'But_BoltzDist_SPC_500'.
# Soft links created for But_BoltzDist_SPC_500
# Inputs created for  ./
# Files generated sucessfully.
# 0

# %% [markdown]
# After the files have been created and ran we can proceed to use the spc_results_to_npz.py to extract the potential energy and forces from the cp2k outputs to generate the npz training dataset.

# %%
# Define name of the SPC npz data set for the Boltzmann Distribution 
BD_output_name = 'But_BoltzDist_2500_SPC'
os.system(f'python spc_results_to_npz.py --input {Butane_BoltzDist_CLC_path} --samples {int(num_samples)} --name {name} --output {BD_output_name}')

# Define name of the SPC npz data set for the Uniform Distribution 
UD_output_name = 'But_UnivDist_2500_SPC'
os.system(f'python spc_results_to_npz.py --input {Butane_UnivDist_CLC_path} --samples {int(num_samples)} --name {name} --output {UD_output_name}')

# Define name of the SPC npz data set for the Half Left Uniform Distribution 
HLUD_output_name = 'But_HalfLeft_UnivDist_2500_SPC'
os.system(f'python spc_results_to_npz.py --input {Butane_HL_UnivDist_CLC_path} --samples {int(num_samples)} --name {name} --output {HLUD_output_name}')

# Define name of the SPC npz data set for the Half Right Uniform Distribution 
HRUD_output_name = 'But_HalfRight_UnivDist_2500_SPC'
os.system(f'python spc_results_to_npz.py --input {Butane_HR_UnivDist_CLC_path} --samples {int(num_samples)} --name {name} --output {HRUD_output_name}')

# Define name of the SPC npz data set for the Bias Left Distribution 
BiasLeftD_output_name = 'But_BiasLeftt_Dist_2500_SPC'
os.system(f'python spc_results_to_npz.py --input {Butane_Left_BiasDist_CLC_path} --samples {int(num_samples)} --name {name} --output {BiasLeftD_output_name}')

# Define name of the SPC npz data set for the Bias Right Distribution 
BiasRightD_output_name = 'But_BiasRight_Dist_2500_SPC'
os.system(f'python spc_results_to_npz.py --input {Butane_Right_BiasDist_CLC_path} --samples {int(num_samples)} --name {name} --output {BiasRightD_output_name}')

# Define name of the SPC npz data set for the Bias Half Left Distribution 
BiasHalfLeftD_output_name = 'But_BiasHalfLeftt_Dist_2500_SPC'
os.system(f'python spc_results_to_npz.py --input {Butane_LeftHalf_BiasDist_CLC_path} --samples {int(num_samples)} --name {name} --output {BiasHalfLeftD_output_name}')

# Define name of the SPC npz data set for the Bias Half Left Distribution 
BiasHalfRightD_output_name = 'But_BiasHalfRight_Dist_2500_SPC'
os.system(f'python spc_results_to_npz.py --input {Butane_RightHalf_BiasDist_CLC_path} --samples {int(num_samples)} --name {name} --output {BiasHalfRightD_output_name}')

# Define name of the SPC npz data set for the Case A (OnlyMin) Distribution 
CaseA_Omin_output_name = 'But_CaseA_Omin_Dist_2500_SPC'
os.system(f'python spc_results_to_npz.py --input {CaseA_Omin_output_name} --samples {int(num_samples)} --name {name} --output {CaseA_Omin_output_name}')
# Out:
# Files in the npz file:
#
# ['R', 'F', 'E', 'z', 'diheds']
#
# Frame:  1
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_1/output_traj.out
# Energy (a.u):  -28.64104183178257
# Energy (kcal/mol):  -17972.524943269855
#
#
# Forces (a.u):
# [[0.04804745, 0.03036109, -0.03152608], [-0.01948292, 0.01495049, 0.00662638], [-0.00363016, -0.02145592, 0.01373386], [-0.01042217, -0.01638502, -0.02482866], [0.01771742, 0.0327294, 0.02961067]]
# Forces (kcal/mol/Angstrom):
# [[ 56.97567727  36.00281941 -37.38428907]
#  [-23.10325651  17.72860564   7.85770084]
#  [ -4.30472012 -25.44288143  16.28590019]
#  [-12.3588285  -19.42970151 -29.4423475 ]
#  [ 21.00968946  38.81121124  35.11295558]]
#
# Frame:  2
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_2/output_traj.out
# Energy (a.u):  -28.631770997910518
# Energy (kcal/mol):  -17966.707407232272
#
#
# Forces (a.u):
# [[0.02900522, -0.01615243, -0.02180115], [0.01064591, -0.00322105, 0.01131087], [-0.0015024, -0.03235786, 0.03613215], [0.00535291, 0.02992601, -0.00689926], [-0.00719059, 0.04248351, 0.02348426]]
# Forces (kcal/mol/Angstrom):
# [[ 34.39500023 -19.15389139 -25.85226243]
#  [ 12.6241441   -3.81958887  13.41266766]
#  [ -1.78157753 -38.37063129  42.8462638 ]
#  [  6.34759332  35.48689239  -8.18128769]
#  [ -8.52675293  50.37784014  27.84812969]]
#
# Frame:  3
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_3/output_traj.out
# Energy (a.u):  -28.648404346801414
# Energy (kcal/mol):  -17977.144991157726
#
#
# Forces (a.u):
# [[-0.03689735, -0.03409113, 0.0324623], [-0.02195102, 0.01767344, -0.03334657], [0.02594471, -0.03027042, -0.02131276], [0.05128266, 0.05095324, 0.02085112], [-0.03600028, 0.02717823, 0.00289847]]
# Forces (kcal/mol/Angstrom):
# [[-43.75365406 -40.42597933  38.49447844]
#  [-26.02998143  20.95753705 -39.54306442]
#  [ 30.76578307 -35.89530102 -25.27311929]
#  [ 60.81205737  60.4214242   24.72569687]
#  [-42.68988958  32.22851705   3.43706672]]
#
# Frame:  4
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_4/output_traj.out
# Energy (a.u):  -28.649294194616093
# Energy (kcal/mol):  -17977.703379087154
#
#
# Forces (a.u):
# [[0.05272684, -0.0091845, 0.0316645], [-0.0162123, -0.01562734, 0.03130544], [-0.03130342, 0.02237923, -0.03961873], [0.00365471, -0.00862891, -0.0065037], [-0.03616219, 0.03600745, -0.02820278]]
# Forces (kcal/mol/Angstrom):
# [[ 62.5245964  -10.89117337  37.54843042]
#  [-19.2248865  -18.53122862  37.12264951]
#  [-37.12025415  26.53776186 -46.98072373]
#  [  4.33383202 -10.23234306  -7.71222432]
#  [-42.88188586  42.69839191 -33.44344999]]
#
# Frame:  5
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_5/output_traj.out
# Energy (a.u):  -28.655835462277594
# Energy (kcal/mol):  -17981.808086482135
#
#
# Forces (a.u):
# [[-0.01182478, -0.07593187, -0.00268171], [-0.01595783, 0.00386657, -0.00608041], [0.01519237, 0.02583096, -0.0134556], [0.03333781, 0.01566831, -0.00630723], [-0.03866172, 0.04974653, 0.00615549]]
# Forces (kcal/mol/Angstrom):
# [[-14.02207295 -90.04160928  -3.18002815]
#  [-18.92313061   4.58506007  -7.21027813]
#  [ 18.01543204  30.63089593 -15.95593363]
#  [ 39.53267662  18.57981171  -7.47924606]
#  [-45.84588113  58.99048209   7.29930957]]
#
# Frame:  6
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_6/output_traj.out
# Energy (a.u):  -28.638519918585505
# Energy (kcal/mol):  -17970.942418859424
#
#
# Forces (a.u):
# [[-0.0218817, -0.0218683, 0.03022094], [-0.02603087, -0.02640929, 0.00958878], [-0.01399588, 0.00176858, -0.00105796], [-0.01719947, 0.02298731, -0.06294129], [0.06862135, 0.00736622, 0.01873965]]
# Forces (kcal/mol/Angstrom):
# [[-25.94778032 -25.93189031  35.83662659]
#  [-30.86795341 -31.31669181  11.3705771 ]
#  [-16.59660902   2.09721938  -1.25455123]
#  [-20.39549345  27.25883592 -74.63710615]
#  [ 81.37264083   8.73501868  22.22187131]]
#
# Frame:  7
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_7/output_traj.out
# Energy (a.u):  -28.633903256877574
# Energy (kcal/mol):  -17968.04541992385
#
#
# Forces (a.u):
# [[0.00025775, -0.01534817, -0.02339888], [-0.01411241, 0.01366685, 0.00544053], [-0.00556301, -0.01029424, -0.00232709], [0.00805833, 0.00593639, 0.01729296], [0.04572546, -0.0553951, 0.04361325]]
# Forces (kcal/mol/Angstrom):
# [[  0.30564537 -18.20018296 -27.74688429]
#  [-16.73479275  16.20643832   6.45149496]
#  [ -6.59673432 -12.20712641  -2.75951229]
#  [  9.55573729   7.03949618  20.50635586]
#  [ 54.22221267 -65.68867526  51.7175096 ]]
#
# Frame:  8
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_8/output_traj.out
# Energy (a.u):  -28.661591643646872
# Energy (kcal/mol):  -17985.42014479499
#
#
# Forces (a.u):
# [[-0.0179107, 0.0030313, -0.00167598], [0.02681908, -0.00974151, -0.00710973], [-0.00799509, 0.00428748, -0.02317919], [-0.00729449, 0.00090726, 0.00760261], [0.00100958, 0.02947437, 0.014342]]
# Forces (kcal/mol/Angstrom):
# [[-21.23888495   3.59457933  -1.98741235]
#  [ 31.80262942 -11.55168755  -8.43086744]
#  [ -9.48074596   5.08418401 -27.48637126]
#  [ -8.64995974   1.075848     9.01533492]
#  [  1.19718121  34.95132817  17.0070454 ]]
#
# Frame:  9
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_9/output_traj.out
# Energy (a.u):  -28.656748906860187
# Energy (kcal/mol):  -17982.381281606857
#
#
# Forces (a.u):
# [[0.0493533, 0.0029424, -0.01543939], [-0.03569306, -0.01516709, -0.00019794], [0.00255228, -0.00168315, -0.0058415], [-0.00292932, 0.0045296, 0.00624424], [-0.00566283, 0.02999768, 0.00820217]]
# Forces (kcal/mol/Angstrom):
# [[ 58.52418168   3.48915984 -18.30835355]
#  [-42.32558164 -17.98545448  -0.23472142]
#  [  3.02654733  -1.99591469  -6.92697362]
#  [ -3.4736493    5.371295     7.40455119]
#  [ -6.71510298  35.57188018   9.72630578]]
#
# Frame:  10
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_10/output_traj.out
# Energy (a.u):  -28.6668434737463
# Energy (kcal/mol):  -17988.715717910458
#
#
# Forces (a.u):
# [[0.02367987, 0.03963702, 0.01324219], [-0.00359402, -0.01374057, 0.00310725], [-0.01338596, -0.01423232, -0.02287345], [-0.00797686, 0.00668195, -0.00139098], [-0.01717039, -0.00738597, 0.02435911]]
# Forces (kcal/mol/Angstrom):
# [[ 28.08008814  47.0024124   15.70286756]
#  [ -4.26186454 -16.29385705   3.68464244]
#  [-15.87335305 -16.87698455 -27.12381834]
#  [ -9.45912844   7.92359692  -1.64945335]
#  [-20.36100978  -8.75843865  28.88554523]]
#
# Frame:  11
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_11/output_traj.out
# Energy (a.u):  -28.65053605505773
# Energy (kcal/mol):  -17978.4826582731
#
#
# Forces (a.u):
# [[0.01215418, -0.01204097, -0.02354214], [0.0150524, -0.00278708, -0.00775016], [-0.00596495, 0.00103994, 0.00602427], [-0.0278075, 0.00976293, 0.00968237], [-0.02410237, -0.02292632, -0.00191155]]
# Forces (kcal/mol/Angstrom):
# [[ 14.4126824  -14.2784356  -27.91676501]
#  [ 17.84945267  -3.30497811  -9.19030281]
#  [ -7.07336323   1.23318274   7.14370613]
#  [-32.97471865  11.57708784  11.48155809]
#  [-28.58109753 -27.18651269  -2.26675621]]
#
# Frame:  12
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_12/output_traj.out
# Energy (a.u):  -28.6356949718439
# Energy (kcal/mol):  -17969.169738030454
#
#
# Forces (a.u):
# [[-0.02105115, 0.05201888, 0.02351922], [0.01831682, -0.01175915, 0.00655249], [-0.01378599, -0.01269988, -0.0089], [0.02319435, -0.01367769, 0.00158782], [0.05547548, -0.0532038, -0.02068455]]
# Forces (kcal/mol/Angstrom):
# [[-24.96289665  61.68508254  27.88958599]
#  [ 21.7204706  -13.94424752   7.77008053]
#  [-16.34771704 -15.05978495 -10.55380728]
#  [ 27.50434831 -16.21929262   1.88287037]
#  [ 65.78399155 -63.09018561 -24.52817465]]
#
# Frame:  13
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_13/output_traj.out
# Energy (a.u):  -28.638340379367904
# Energy (kcal/mol):  -17970.829756300373
#
#
# Forces (a.u):
# [[0.01679638, -0.01011143, 0.02231077], [-0.00943847, 0.01058181, 0.01043235], [-0.02916154, 0.00759492, -0.0053842], [-0.00791778, -0.01639514, -0.01797342], [0.00872842, 0.06882694, -0.0435012]]
# Forces (kcal/mol/Angstrom):
# [[ 19.91750085 -11.99034647  26.45658055]
#  [-11.19233634  12.54813297  12.37090016]
#  [-34.58036778   9.00621596  -6.38469766]
#  [ -9.38907014 -19.44170201 -21.31325965]
#  [ 10.35034411  81.61643378 -51.58463836]]
#
# Frame:  14
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_14/output_traj.out
# Energy (a.u):  -28.663092071705996
# Energy (kcal/mol):  -17986.361677609213
#
#
# Forces (a.u):
# [[-0.04150689, 0.02891114, 0.00309137], [-0.00165741, 0.00148878, 0.00164094], [0.00290395, -0.00569851, 0.00998394], [0.00481009, -0.0084792, -0.01387195], [0.01405847, -0.00482092, -0.03128811]]
# Forces (kcal/mol/Angstrom):
# [[-49.21974359  34.28343819   3.6658116 ]
#  [ -1.96539165   1.76542665   1.94586118]
#  [  3.44356502  -6.75741307  11.83916614]
#  [  5.70390594 -10.05481379 -16.44965022]
#  [ 16.67082956  -5.71674838 -37.10209923]]
#
# Frame:  15
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_15/output_traj.out
# Energy (a.u):  -28.646682337187286
# Energy (kcal/mol):  -17976.064413819644
#
#
# Forces (a.u):
# [[-0.01347667, -0.00712814, -0.02107876], [0.00206378, 0.00721352, -0.01508554], [0.00075478, 0.00732863, 0.00735651], [0.01983842, 0.0026745, -0.01641432], [0.04579094, 0.0076383, 0.00701243]]
# Forces (kcal/mol/Angstrom):
# [[-15.98091888  -8.45269841 -24.99563717]
#  [  2.44727375   8.55394381 -17.88875078]
#  [  0.89503401   8.69044367   8.72350436]
#  [ 23.5248159    3.17147838 -19.46444606]
#  [ 54.29986023   9.05765687   8.31548706]]
#
# Frame:  16
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_16/output_traj.out
# Energy (a.u):  -28.65077941505218
# Energy (kcal/mol):  -17978.635368973923
#
#
# Forces (a.u):
# [[-0.02593358, -0.0059707, -0.04473885], [0.00016697, 0.00906958, -0.01095419], [0.01070764, -0.02763833, 0.07626278], [0.01951339, 0.01134369, 0.00251506], [-0.01745587, 0.02659685, -0.0142243]]
# Forces (kcal/mol/Angstrom):
# [[-30.75258488  -7.0801817  -53.05226977]
#  [  0.19799654  10.75489882 -12.98970901]
#  [ 12.69734483 -32.77411331  90.43400932]
#  [ 23.13938848  13.45158631   2.98241107]
#  [-20.69953797  31.53910441 -16.86747426]]
#
# Frame:  17
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_17/output_traj.out
# Energy (a.u):  -28.64059286769069
# Energy (kcal/mol):  -17972.243214051086
#
#
# Forces (a.u):
# [[0.00741555, -0.04389795, 0.01863679], [0.00252758, 0.01301407, -0.01165203], [-0.00077063, 0.00189223, -0.01985658], [-0.00064104, 0.00987717, 0.00289318], [0.02661726, -0.00639713, -0.01679923]]
# Forces (kcal/mol/Angstrom):
# [[  8.79351524 -52.05511285  22.09989776]
#  [  2.99725755  15.43235806 -13.81722237]
#  [ -0.91382927   2.24384615 -23.54635041]
#  [ -0.76015872  11.71255603   3.43079373]
#  [ 31.56330701  -7.58585137 -19.92088044]]
#
# Frame:  18
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_18/output_traj.out
# Energy (a.u):  -28.637595592395172
# Energy (kcal/mol):  -17970.36239542281
#
#
# Forces (a.u):
# [[0.02864584, 0.01040467, -0.0146872], [-0.02085638, -0.0028385, 0.03003008], [0.00601314, -0.01018897, -0.01605424], [-0.00211508, 0.01020953, -0.01040696], [0.00770366, -0.04516741, -0.02402676]]
# Forces (kcal/mol/Angstrom):
# [[ 33.96883987  12.33807663 -17.41639082]
#  [-24.73193428  -3.36595303  35.61030079]
#  [  7.13050795 -12.08229503 -19.03745562]
#  [ -2.50810637  12.10667551 -12.34079216]
#  [  9.13516214 -53.56046524 -28.4914376 ]]
#
# Frame:  19
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_19/output_traj.out
# Energy (a.u):  -28.642389010763342
# Energy (kcal/mol):  -17973.37031083634
#
#
# Forces (a.u):
# [[-0.03542941, 0.00016515, 0.00687881], [-0.00632684, 0.00774706, 0.00355982], [-0.02083709, -0.00918192, -0.00492747], [0.03580179, 0.00258829, 0.01969781], [0.03400716, 0.0453833, 0.00259772]]
# Forces (kcal/mol/Angstrom):
# [[-42.01293992   0.19583835   8.15703765]
#  [ -7.50250001   9.18662677   4.22130947]
#  [-24.7090598  -10.88811395  -5.84309761]
#  [ 42.45451596   3.06924875  23.3580776 ]
#  [ 40.32640594  53.81647214   3.08043104]]
#
# Frame:  20
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_20/output_traj.out
# Energy (a.u):  -28.656007644320294
# Energy (kcal/mol):  -17981.91613234427
#
#
# Forces (a.u):
# [[-0.02398959, -0.00554697, -0.00176159], [0.01076734, -0.01366287, -0.00317141], [0.010714, 0.02245084, -0.00103297], [0.00999268, 0.01239285, 0.00547108], [-0.02828132, 0.00230433, 0.00939413]]
# Forces (kcal/mol/Angstrom):
# [[-28.44736063  -6.57771375  -2.08893049]
#  [ 12.76813835 -16.20171875  -3.76072471]
#  [ 12.70488665  26.6226785   -1.22491756]
#  [ 11.84953022  14.69570231   6.48772179]
#  [-33.53658438   2.732523    11.13975703]]
#
# Frame:  21
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_21/output_traj.out
# Energy (a.u):  -28.653024510086905
# Energy (kcal/mol):  -17980.044187366377
#
#
# Forces (a.u):
# [[-0.01849297, 0.05635305, 0.02809029], [0.0001132, -0.00187964, -0.01179074], [-0.01671313, -0.00199349, -0.04513092], [0.04275618, -0.01438246, 0.00221319], [-0.01350646, 0.00399851, -0.01633724]]
# Forces (kcal/mol/Angstrom):
# [[-21.92935297  66.82463253  33.31005699]
#  [  0.13423494  -2.22891667 -13.9817076 ]
#  [-19.81878125  -2.36392239 -53.51719463]
#  [ 50.70117796 -17.05502372   2.62444727]
#  [-16.01624448   4.7415173  -19.37304298]]
#
# Frame:  22
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_22/output_traj.out
# Energy (a.u):  -28.65651668329127
# Energy (kcal/mol):  -17982.235559118504
#
#
# Forces (a.u):
# [[0.01612627, 0.04925937, 0.05117972], [0.00138868, 0.00876415, -0.01646696], [-0.00436132, -0.04762218, -0.0406794], [0.02766391, -0.01254476, 0.0132209], [-0.06969621, 0.04349051, -0.01066863]]
# Forces (kcal/mol/Angstrom):
# [[ 19.12287031  58.41279751  60.68998895]
#  [  1.64672597  10.39271349 -19.52686768]
#  [ -5.17174503 -56.47138316 -48.23848854]
#  [ 32.80444661 -14.87584039  15.67762143]
#  [-82.64723243  51.57196193 -12.65108595]]
#
# Frame:  23
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_23/output_traj.out
# Energy (a.u):  -28.642688694860222
# Energy (kcal/mol):  -17973.55836544476
#
#
# Forces (a.u):
# [[0.01458831, 0.00593693, -0.02233516], [0.00176099, -0.01088863, -0.00083778], [0.02914532, 0.00541294, 0.00314101], [-0.01927898, 0.01539257, 0.02002323], [-0.01833246, -0.04857244, 0.0160273]]
# Forces (kcal/mol/Angstrom):
# [[ 17.29912498   7.04013652 -26.48550273]
#  [  2.088219   -12.91196658  -0.99345715]
#  [ 34.56113376   6.41877816   3.72467575]
#  [-22.86142017  18.25283341  23.74396748]
#  [-21.73901684 -57.59822146  19.0055096 ]]
#
# Frame:  24
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_24/output_traj.out
# Energy (a.u):  -28.64142621764114
# Energy (kcal/mol):  -17972.766149035746
#
#
# Forces (a.u):
# [[0.0066934, -0.0319441, 0.0748414], [0.0339678, -0.0266179, -0.00988445], [0.00191367, 0.00961334, 0.00639772], [-0.00023955, 0.03116667, 0.01357823], [-0.10122492, 0.01450806, -0.0437611]]
# Forces (kcal/mol/Angstrom):
# [[   7.93717457  -37.87998598   88.74850701]
#  [  40.27973202  -31.56406594  -11.72118881]
#  [   2.26927016   11.39970087    7.586551  ]
#  [  -0.28406343   36.95809313   16.10135086]
#  [-120.03464021   17.20396284  -51.89283324]]
#
# Frame:  25
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_25/output_traj.out
# Energy (a.u):  -28.650951093419344
# Energy (kcal/mol):  -17978.743098774892
#
#
# Forces (a.u):
# [[-0.02589784, -0.03014967, -0.01227101], [0.01681132, 0.02615075, 0.02173946], [-0.0392608, 0.00807448, 0.00523163], [0.02393955, -0.01751631, 0.00436113], [-0.01850705, 0.02595451, -0.02433747]]
# Forces (kcal/mol/Angstrom):
# [[-30.71020364 -35.75211313 -14.55122188]
#  [ 19.93521702  31.01010964  25.77910913]
#  [-46.5562828    9.5748883    6.20377694]
#  [ 28.38802215 -20.77120899   5.17151973]
#  [-21.94604933  30.77740412 -28.85988406]]
#
# Frame:  26
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_26/output_traj.out
# Energy (a.u):  -28.644915443541592
# Energy (kcal/mol):  -17974.955671326763
#
#
# Forces (a.u):
# [[0.01561022, -0.04978227, -0.05372647], [0.03461736, 0.03983132, 0.00353481], [-0.03984307, -0.0059697, 0.02921659], [0.00719211, 0.00080082, 0.02773218], [-0.04298258, -0.03124035, 0.02391593]]
# Forces (kcal/mol/Angstrom):
# [[ 18.51092736 -59.03286333 -63.70997869]
#  [ 41.04999394  47.23281743   4.19165208]
#  [-47.24675082  -7.07899588  34.64564723]
#  [  8.52855538   0.94962921  32.88540261]
#  [-50.96964785 -37.04546442  28.36001306]]
#
# Frame:  27
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_27/output_traj.out
# Energy (a.u):  -28.649804793641486
# Energy (kcal/mol):  -17978.023784810302
#
#
# Forces (a.u):
# [[0.01522073, 0.06452798, 0.00196612], [0.01252954, -0.00841047, -0.00712873], [-0.02871928, -0.00613381, 0.00350492], [0.00555771, -0.04308266, 0.02158865], [-0.0569514, 0.0210749, 0.00843174]]
# Forces (kcal/mol/Angstrom):
# [[ 18.04906192  76.51863655   2.33146647]
#  [ 14.85779219  -9.97331231  -8.45339804]
#  [-34.05592656  -7.27360097   4.15620789]
#  [  6.59044947 -51.08832482  25.60027546]
#  [-67.53416855  24.9910599    9.99853472]]
#
# Frame:  28
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_28/output_traj.out
# Energy (a.u):  -28.64875714376595
# Energy (kcal/mol):  -17977.366374593505
#
#
# Forces (a.u):
# [[0.00699822, -0.06141001, -0.01157137], [-0.00204703, 0.00519732, 0.01037273], [0.02497741, 0.01825341, -0.00462604], [-0.00663466, 0.03484191, 0.01276489], [-0.021171, -0.07560071, -0.03474513]]
# Forces (kcal/mol/Angstrom):
# [[  8.29863654 -72.82128211 -13.72157404]
#  [ -2.42741125   6.16309142  12.30020151]
#  [ 29.61873838  21.64527768  -5.48565558]
#  [ -7.86751944  41.31627006  15.13687517]
#  [-25.1050173  -89.64891278 -41.2015063 ]]
#
# Frame:  29
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_29/output_traj.out
# Energy (a.u):  -28.6512499942667
# Energy (kcal/mol):  -17978.930661886814
#
#
# Forces (a.u):
# [[0.00097967, 0.09384324, 3.607e-05], [0.00091185, -0.00283292, 0.01214696], [8.01e-06, -0.00286404, -0.00684807], [-0.0107652, -0.06908718, -0.00161831], [0.04962875, 0.00923877, 0.01243364]]
# Forces (kcal/mol/Angstrom):
# [[ 1.16171330e+00  1.11281289e+02  4.27725650e-02]
#  [ 1.08129092e+00 -3.35933615e+00  1.44041208e+01]
#  [ 9.49842655e-03 -3.39623890e+00 -8.12058551e+00]
#  [-1.27656007e+01 -8.19250318e+01 -1.91902605e+00]
#  [ 5.88508161e+01  1.09555279e+01  1.47440720e+01]]
#
# Frame:  30
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_30/output_traj.out
# Energy (a.u):  -28.65074382549546
# Energy (kcal/mol):  -17978.613036190094
#
#
# Forces (a.u):
# [[0.02422648, 0.03005545, 0.06071459], [-0.00757976, -0.00375639, 5.731e-05], [-0.01617297, 0.00382017, -0.01220212], [-0.00716966, -0.00403919, -0.03476443], [0.00972682, -0.01317767, 0.03706584]]
# Forces (kcal/mol/Angstrom):
# [[ 2.87282698e+01  3.56403851e+01  7.19966384e+01]
#  [-8.98823891e+00 -4.45440631e+00  6.79594040e-02]
#  [-1.91782482e+01  4.53003797e+00 -1.44695307e+01]
#  [-8.50193370e+00 -4.78975650e+00 -4.12243926e+01]
#  [ 1.15342678e+01 -1.56263584e+01  4.39534530e+01]]
#
# Frame:  31
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_31/output_traj.out
# Energy (a.u):  -28.652001489188827
# Energy (kcal/mol):  -17979.40223206614
#
#
# Forces (a.u):
# [[-0.03968066, 0.0054084, -0.02486605], [-0.00023117, -0.03224233, 0.00828783], [0.03635828, -0.00395046, -0.00576362], [0.00028934, 0.0057497, 0.00962295], [-0.06448234, 0.02285013, -0.02288108]]
# Forces (kcal/mol/Angstrom):
# [[-47.05416163   6.41339453 -29.48668535]
#  [ -0.27412625 -38.23363339   9.82788321]
#  [ 43.11441351  -4.6845386   -6.83462188]
#  [  0.34310546   6.81811525  11.41109661]
#  [-76.46451567  27.09616499 -27.13286615]]
#
# Frame:  32
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_32/output_traj.out
# Energy (a.u):  -28.65498192753237
# Energy (kcal/mol):  -17981.27248534763
#
#
# Forces (a.u):
# [[0.02339193, -0.02140825, 0.0689994], [-0.02158708, 0.00802139, -0.00986179], [0.02975098, 0.02477883, 0.00059141], [-0.01043448, 0.01350029, -0.02972206], [-0.01771936, -0.04612374, -0.00392503]]
# Forces (kcal/mol/Angstrom):
# [[ 27.73864283 -25.38635334  81.82094047]
#  [-25.59841372   9.51193306 -11.6943181 ]
#  [ 35.27933813  29.38325803   0.70130642]
#  [-12.37342596  16.00892797 -35.24504419]
#  [-21.01198996 -54.69450147  -4.65438317]]
#
# Frame:  33
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_33/output_traj.out
# Energy (a.u):  -28.654605966109447
# Energy (kcal/mol):  -17981.036565994877
#
#
# Forces (a.u):
# [[-0.00617629, -0.00336571, 0.02120004], [0.00212974, -0.00532463, 0.01748689], [0.00793085, 0.00503004, -0.00046232], [-0.00554963, 0.00895813, -0.02004949], [-0.001906, 0.02053552, 0.03903588]]
# Forces (kcal/mol/Angstrom):
# [[ -7.32397465  -3.99112974  25.13945354]
#  [  2.52549051  -6.3140583   20.73632214]
#  [  9.40456882   5.96472728  -0.54822878]
#  [ -6.58086803  10.62273906 -23.77510714]
#  [ -2.26017491  24.35145174  46.28956794]]
#
# Frame:  34
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_34/output_traj.out
# Energy (a.u):  -28.652796320764985
# Energy (kcal/mol):  -17979.90099640621
#
#
# Forces (a.u):
# [[0.02045206, 0.00530539, 0.01070081], [-0.00462649, -0.00181547, 0.00699657], [0.01268408, 0.00385353, -0.01899773], [0.01571963, -0.01317286, 0.01785726], [0.00466316, 0.02123277, -0.01767971]]
# Forces (kcal/mol/Angstrom):
# [[ 24.25248312   6.2912431   12.68924567]
#  [ -5.4861892   -2.15282253   8.29667993]
#  [ 15.04104897   4.56959696 -22.527908  ]
#  [ 18.64066804 -15.62065458  21.17551468]
#  [  5.52967325  25.17826547 -20.96497215]]
#
# Frame:  35
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_35/output_traj.out
# Energy (a.u):  -28.648307938449598
# Energy (kcal/mol):  -17977.0844940041
#
#
# Forces (a.u):
# [[9.15e-05, 0.04309828, -0.01357798], [0.02546317, -0.01600677, 0.04050538], [0.0182047, -0.0027808, -0.03334764], [-0.01257798, -0.00219923, -0.00410845], [0.01490246, -0.05069782, 0.04864698]]
# Forces (kcal/mol/Angstrom):
# [[  0.10850263  51.10684734 -16.10105441]
#  [ 30.19476281 -18.9811647   48.03213196]
#  [ 21.58751634  -3.29753116 -39.54433325]
#  [-14.91523336  -2.60789321  -4.87188646]
#  [ 17.67165066 -60.11854179  57.68661256]]
#
# Frame:  36
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_36/output_traj.out
# Energy (a.u):  -28.656441056391415
# Energy (kcal/mol):  -17982.188102522756
#
#
# Forces (a.u):
# [[0.02293981, 0.0111584, 0.04123719], [-0.00618682, 0.01634229, -0.03303881], [0.00324478, -0.01543536, -0.01022243], [0.00852318, 0.00163117, 0.00329735], [-0.04484151, -0.01428528, 0.00991988]]
# Forces (kcal/mol/Angstrom):
# [[ 27.20250942  13.23186553  48.89992766]
#  [ -7.33646135  19.37903137 -39.17811613]
#  [  3.8477284  -18.30357469 -12.1219726 ]
#  [ 10.1069662    1.93427571   3.91006702]
#  [-53.17400616 -16.93978563  11.76320245]]
#
# Frame:  37
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_37/output_traj.out
# Energy (a.u):  -28.65146155011265
# Energy (kcal/mol):  -17979.06341518331
#
#
# Forces (a.u):
# [[0.01099782, -0.0468356, -0.0082358], [0.0009413, 0.0136739, 0.01055587], [-0.00475885, 0.01405611, 0.01186711], [-0.00462295, 0.00023972, 0.00228341], [0.02784194, -0.01830303, -0.01763208]]
# Forces (kcal/mol/Angstrom):
# [[ 13.04144638 -55.53864004  -9.76618495]
#  [  1.11621335  16.21479836  12.51737277]
#  [ -5.64314447  16.66803102  14.07226876]
#  [ -5.48199139   0.28426502   2.70771563]
#  [ 33.01555833 -21.70411812 -20.9084915 ]]
#
# Frame:  38
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_38/output_traj.out
# Energy (a.u):  -28.65401535954794
# Energy (kcal/mol):  -17980.665954785247
#
#
# Forces (a.u):
# [[-0.00405523, 0.03954281, -0.01033368], [-0.01529778, -0.01881087, -0.00673854], [-0.0082862, 0.00288085, 0.03158263], [0.00764354, -0.01939088, -0.0058781], [0.01115642, 0.02233893, -0.02940865]]
# Forces (kcal/mol/Angstrom):
# [[ -4.80877707  46.8906962  -12.2538952 ]
#  [-18.14042943 -22.30632548  -7.99070253]
#  [ -9.82595033   3.41617255  37.45134725]
#  [  9.06387057 -22.99411355  -6.97037467]
#  [ 13.2295176   26.48997327 -34.87339602]]
#
# Frame:  39
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_39/output_traj.out
# Energy (a.u):  -28.651111325784633
# Energy (kcal/mol):  -17978.843646101304
#
#
# Forces (a.u):
# [[-0.05050812, 0.04638806, 0.02433406], [0.00646768, -0.01752361, -0.02477174], [-0.00477673, 0.0027794, 0.00787682], [0.01216011, 0.02430608, -0.0291216], [0.0112866, -0.01916097, -0.01714409]]
# Forces (kcal/mol/Angstrom):
# [[-59.89359154  55.00793769  28.85584041]
#  [  7.66951104 -20.77986549 -29.37485056]
#  [ -5.66434695   3.29587101   9.34049891]
#  [ 14.41971432  28.82266114 -34.53300609]
#  [ 13.38388778 -22.72148143 -20.32982268]]
#
# Frame:  40
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_40/output_traj.out
# Energy (a.u):  -28.659425176062612
# Energy (kcal/mol):  -17984.060665872206
#
#
# Forces (a.u):
# [[0.00388444, 0.03901226, -0.02343367], [0.01401084, -0.00474326, 0.014542], [-0.02080049, -0.01593866, -0.01529722], [-0.00733275, 0.02321961, 0.0046429], [0.03328892, -0.00758728, 0.0041593]]
# Forces (kcal/mol/Angstrom):
# [[  4.60625069  46.26155884 -27.788139  ]
#  [ 16.6143489   -5.62465752  17.24420961]
#  [-24.66565875 -18.90039842 -18.13976538]
#  [ -8.69532925  27.53430215   5.50564852]
#  [ 39.47470183  -8.99715628   4.93218546]]
#
# Frame:  41
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_41/output_traj.out
# Energy (a.u):  -28.653909282651917
# Energy (kcal/mol):  -17980.59939052858
#
#
# Forces (a.u):
# [[-0.04327975, -0.01488334, -0.02026882], [0.0075472, 0.00754963, 0.00482783], [0.01046396, -0.00532934, 0.00141264], [0.02151648, 0.00160068, 0.00806277], [0.0051492, 0.07415395, 0.0307412]]
# Forces (kcal/mol/Angstrom):
# [[-51.32203829 -17.64897776 -24.03519327]
#  [  8.94962858   8.95251012   5.72494241]
#  [ 12.40838396  -6.31964352   1.67513824]
#  [ 25.51469475   1.89812003   9.56100233]
#  [  6.10602971  87.93331433  36.45356185]]
#
# Frame:  42
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_42/output_traj.out
# Energy (a.u):  -28.64749564022333
# Energy (kcal/mol):  -17976.574769175695
#
#
# Forces (a.u):
# [[-0.01762378, -0.03089269, 0.03174387], [0.00246635, -0.0151803, -0.00927356], [0.01584636, 0.02947268, -0.03306211], [-0.00109626, -0.00617687, 0.01105464], [-0.03330877, 0.08695158, 0.01240728]]
# Forces (kcal/mol/Angstrom):
# [[-20.89864918 -36.63320188  37.64254903]
#  [  2.92464973 -18.00111918 -10.99678259]
#  [ 18.79094714  34.94932414 -39.20574576]
#  [ -1.29996818  -7.32466243  13.10882473]
#  [-39.49824038 103.10901328  14.71281371]]
#
# Frame:  43
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_43/output_traj.out
# Energy (a.u):  -28.63666912875453
# Energy (kcal/mol):  -17969.781030715887
#
#
# Forces (a.u):
# [[0.03932808, 0.00486039, -0.02699981], [-0.01790329, 0.00134754, 0.04416489], [-0.02231101, -0.00740476, -0.01345518], [0.00013425, -0.011663, -0.01190168], [0.0415308, 0.09868689, -0.01840843]]
# Forces (kcal/mol/Angstrom):
# [[ 46.63606484   5.76355274 -32.01694285]
#  [-21.23009802   1.59794129  52.37165592]
#  [-26.45686515  -8.78072023 -15.95543558]
#  [  0.15919648 -13.83023082 -14.11326259]
#  [ 49.24809657 117.02499083 -21.82910366]]
#
# Frame:  44
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_44/output_traj.out
# Energy (a.u):  -28.652550918280138
# Energy (kcal/mol):  -17979.747004023324
#
#
# Forces (a.u):
# [[-0.00730221, -0.04542027, -0.00343105], [0.00426592, 0.01551219, -0.00497726], [0.00795562, 0.01887906, 0.02226893], [0.00095371, -0.0005562, -0.01533224], [0.00871449, -0.04725616, 0.00431076]]
# Forces (kcal/mol/Angstrom):
# [[ -8.65911428 -53.86031194  -4.06861129]
#  [  5.0586177   18.39468132  -5.90213964]
#  [  9.43394161  22.38718662  26.4069658 ]
#  [  1.13092939  -0.65955366 -18.18129283]
#  [ 10.33382562 -56.03734894   5.11178992]]
#
# Frame:  45
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_45/output_traj.out
# Energy (a.u):  -28.645120752795314
# Energy (kcal/mol):  -17975.084504827486
#
#
# Forces (a.u):
# [[0.01564007, 0.03643029, -0.03858643], [-0.01613005, -0.02456674, 0.02199113], [-0.01166041, -0.02281319, -0.01013774], [0.00267355, 0.00721494, 0.01258146], [-0.0322556, -0.0458112, -0.06402146]]
# Forces (kcal/mol/Angstrom):
# [[ 18.54632412  43.19980448 -45.75660067]
#  [-19.12735271 -29.13175725  26.07754471]
#  [-13.82715955 -27.05236076 -12.02154542]
#  [  3.17035185   8.55562768  14.91936002]
#  [-38.24936923 -54.32388496 -75.91799447]]
#
# Frame:  46
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_46/output_traj.out
# Energy (a.u):  -28.631792373457905
# Energy (kcal/mol):  -17966.720820590654
#
#
# Forces (a.u):
# [[0.02037397, -0.02471907, -0.01528131], [-0.01448161, -0.02433247, -0.0097637], [0.01814299, 0.00933271, -0.01641548], [-0.02974783, 0.0485487, -0.02954239], [-0.02554157, -0.04350796, 0.05072192]]
# Forces (kcal/mol/Angstrom):
# [[ 24.15988236 -29.31239337 -18.12089896]
#  [-17.17259787 -28.85395495 -11.57800092]
#  [ 21.51433932  11.06692391 -19.46582161]
#  [-35.2756028   57.57007007 -35.03198772]
#  [-30.28773118 -51.59265451  60.14712008]]
#
# Frame:  47
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_47/output_traj.out
# Energy (a.u):  -28.65785246575298
# Energy (kcal/mol):  -17983.073775261368
#
#
# Forces (a.u):
# [[-0.01109098, -0.03135829, -0.01616656], [-0.01941749, 0.02786995, 0.03076993], [0.0036398, -0.01096204, -0.01595576], [0.01188473, 0.00055639, 0.01074723], [0.02048118, 0.03248611, -0.0296742]]
# Forces (kcal/mol/Angstrom):
# [[-13.15191747 -37.18532015 -19.17064704]
#  [-23.02566824  33.04877318  36.48763049]
#  [  4.31615143 -12.99901771 -18.92067596]
#  [ 14.09316292   0.65977897  12.74429149]
#  [ 24.28701423  38.52271284 -35.18829079]]
#
# Frame:  48
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_48/output_traj.out
# Energy (a.u):  -28.644205589850845
# Energy (kcal/mol):  -17974.510231414417
#
#
# Forces (a.u):
# [[-0.02846558, -0.06055542, -0.04013978], [0.0299944, 0.02603697, 0.00091481], [-0.01831131, 0.02723679, -0.01182487], [-0.00551631, 0.00151307, 0.01857377], [-0.0383339, -0.0183685, 0.01330821]]
# Forces (kcal/mol/Angstrom):
# [[-33.75508376 -71.8078913  -47.59859578]
#  [ 35.56799069  30.87518692   1.08480095]
#  [-21.71393672  32.29795873 -14.02217968]
#  [ -6.54135648   1.79423025  22.02516731]
#  [-45.45714528 -21.78175383  15.78115546]]
#
# Frame:  49
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_49/output_traj.out
# Energy (a.u):  -28.655410713780803
# Energy (kcal/mol):  -17981.541552778577
#
#
# Forces (a.u):
# [[0.04186551, -0.00969859, -0.0023857], [0.00689502, -0.00394564, -0.01124895], [-0.00193752, 0.02160453, -0.00972204], [-0.04552158, -0.00244377, -0.01386682], [0.01257168, 0.00994303, -0.03509665]]
# Forces (kcal/mol/Angstrom):
# [[ 49.64500273 -11.50079211  -2.82901326]
#  [  8.17625981  -4.67882294 -13.33924162]
#  [ -2.29755199  25.6191063  -11.52859961]
#  [-53.98044747  -2.89787389 -16.44356696]
#  [ 14.90776269  11.79065421 -41.61834611]]
#
# Frame:  50
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_50/output_traj.out
# Energy (a.u):  -28.646545724896058
# Energy (kcal/mol):  -17975.978688313357
#
#
# Forces (a.u):
# [[-0.03318941, 0.00629508, -0.02115812], [0.02927463, -0.02282528, 0.03447385], [-0.00098523, 0.00535958, -0.01101234], [-0.00031091, 0.00638493, 0.00123864], [0.05790096, -0.03798967, 0.02279815]]
# Forces (kcal/mol/Angstrom):
# [[-39.35670078   7.46483833 -25.08974393]
#  [ 34.71447228 -27.06669734  40.87981676]
#  [ -1.16830647   6.35550275 -13.0586645 ]
#  [ -0.36868362   7.57138435   1.46880538]
#  [ 68.66017678 -45.0489501   27.03452601]]
#
# Frame:  51
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_51/output_traj.out
# Energy (a.u):  -28.646187763813913
# Energy (kcal/mol):  -17975.75406434488
#
#
# Forces (a.u):
# [[0.06083605, -0.00118959, 0.01693831], [0.0128387, 0.00839743, -0.01736392], [-0.03022982, 0.00766337, 0.02633422], [-0.0150282, 0.00139664, -0.01305738], [-0.00400544, -0.06089738, -0.02544024]]
# Forces (kcal/mol/Angstrom):
# [[ 72.14066826  -1.41064085  20.08580443]
#  [ 15.22440062   9.9578492  -20.59050172]
#  [-35.84715668   9.08738541  31.22767223]
#  [-17.8207558    1.6561651  -15.48371597]
#  [ -4.74973504 -72.21339467 -30.16757193]]
#
# Frame:  52
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_52/output_traj.out
# Energy (a.u):  -28.652452638251177
# Energy (kcal/mol):  -17979.685332374567
#
#
# Forces (a.u):
# [[0.07475664, -0.01937638, 0.03833823], [-0.01269957, -0.00678804, 0.0045818], [-0.02556502, 0.05781804, -0.03982153], [-0.01480035, -0.02726195, 0.00566971], [0.00815522, -0.02353041, -0.04504106]]
# Forces (kcal/mol/Angstrom):
# [[ 88.64799681 -22.97691914  45.46227988]
#  [-15.05941734  -8.04940067   5.43319485]
#  [-30.31553868  68.5618485  -47.22120824]
#  [-17.55056647 -32.32779398   6.72326143]
#  [  9.67063149 -27.90285533 -53.41063675]]
#
# Frame:  53
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_53/output_traj.out
# Energy (a.u):  -28.65627482907988
# Energy (kcal/mol):  -17982.08379331081
#
#
# Forces (a.u):
# [[-0.00498861, -0.02524938, 0.03368316], [0.00940812, 0.01097851, -0.00879376], [-0.02178722, 0.00437108, -0.01530923], [0.02494493, 0.00829084, -0.01040337], [0.02226347, -0.04051491, -0.00637758]]
# Forces (kcal/mol/Angstrom):
# [[ -5.91559871 -29.94124613  39.94219992]
#  [ 11.15634667  13.01854818 -10.42782565]
#  [-25.83574394   5.18331864 -18.15400709]
#  [ 29.58022291   9.83145254 -12.33653506]
#  [ 26.40049122 -48.04343283  -7.56266857]]
#
# Frame:  54
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_54/output_traj.out
# Energy (a.u):  -28.649978956902686
# Energy (kcal/mol):  -17978.133073905807
#
#
# Forces (a.u):
# [[0.02328663, -0.0584697, -0.00443074], [0.00912817, 0.00259185, -0.01885672], [-0.01951424, 0.02641371, 0.04557706], [0.00178324, -0.0018446, -0.02448683], [0.05013976, 0.02640864, -0.00129805]]
# Forces (kcal/mol/Angstrom):
# [[ 27.61377587 -69.33460064  -5.25406473]
#  [ 10.82437607   3.07347027 -22.36069538]
#  [-23.14039643  31.32193314  54.04623683]
#  [  2.11460352  -2.1873655  -29.03699829]
#  [ 59.4567825   31.31592103  -1.539255  ]]
#
# Frame:  55
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_55/output_traj.out
# Energy (a.u):  -28.640334557630403
# Energy (kcal/mol):  -17972.081122042393
#
#
# Forces (a.u):
# [[-0.01900608, -0.03342418, 0.00069361], [-0.01946603, -0.0125556, -0.0029138], [0.00333012, 0.01753806, 0.02196813], [0.03500129, 0.01135327, -0.02100716], [0.01726912, 0.06381645, -0.03476574]]
# Forces (kcal/mol/Angstrom):
# [[-22.53780961 -39.63509599   0.82249733]
#  [-23.083228   -14.88869469  -3.45524536]
#  [  3.94892637  20.7970006   26.05027083]
#  [ 41.50526621  13.46294647 -24.91073238]
#  [ 20.47808589  75.6748893  -41.22594607]]
#
# Frame:  56
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_56/output_traj.out
# Energy (a.u):  -28.650030234904825
# Energy (kcal/mol):  -17978.165251337687
#
#
# Forces (a.u):
# [[-1.627e-05, 0.04184093, 0.06494019], [-0.04462126, -0.01063427, -0.00096339], [0.01683815, 0.00543797, -0.07485457], [-0.00559946, 0.00038027, -0.00318474], [0.0259322, -0.02861342, 0.01457946]]
# Forces (kcal/mol/Angstrom):
# [[-1.92933084e-02  4.96158553e+01  7.70074438e+01]
#  [-5.29128291e+01 -1.26103411e+01 -1.14240813e+00]
#  [ 1.99670326e+01  6.44845926e+00 -8.87641243e+01]
#  [-6.63995750e+00  4.50932168e-01 -3.77653171e+00]
#  [ 3.07509485e+01 -3.39303955e+01  1.72886305e+01]]
#
# Frame:  57
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_57/output_traj.out
# Energy (a.u):  -28.657633092491267
# Energy (kcal/mol):  -17982.93611646246
#
#
# Forces (a.u):
# [[-0.02316564, -0.03183052, -0.00684209], [0.00529031, 0.02151329, -0.00831556], [0.0371329, 0.02249259, 0.0274709], [0.00345247, -0.01699398, -0.00764192], [-0.00786384, -0.03764745, 0.00675506]]
# Forces (kcal/mol/Angstrom):
# [[-27.47030339 -37.74530043  -8.1134943 ]
#  [  6.27336092  25.51091199  -9.86076603]
#  [ 44.03297421  26.67218653  32.57557129]
#  [  4.09401158 -20.15181909  -9.06194954]
#  [ -9.32510695 -44.64313842   8.01029229]]
#
# Frame:  58
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_58/output_traj.out
# Energy (a.u):  -28.644575734355215
# Energy (kcal/mol):  -17974.7425005957
#
#
# Forces (a.u):
# [[-0.00495703, 0.03628394, -0.02609517], [-0.00496453, 0.00780731, 0.03231313], [-0.00078712, 0.01860114, 0.00212909], [-0.00457573, -0.05376779, -0.0152354], [0.00729097, -0.07971271, 0.01614879]]
# Forces (kcal/mol/Angstrom):
# [[ -5.87815048  43.02625957 -30.94420171]
#  [ -5.88704414   9.25807249  38.31758952]
#  [ -0.93338346  22.05762324   2.52471972]
#  [ -5.42599692 -63.75897682 -18.06645792]
#  [  8.64578565 -94.52500891  19.149575  ]]
#
# Frame:  59
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_59/output_traj.out
# Energy (a.u):  -28.657181469835688
# Energy (kcal/mol):  -17982.6527189698
#
#
# Forces (a.u):
# [[-0.01729678, 0.05122759, -0.00881776], [0.01989107, -0.01059832, -0.00449003], [-0.00223956, -0.01589562, 0.01904504], [0.01944659, -0.02984062, -0.01939091], [-0.03841208, 0.02688703, 0.00137212]]
# Forces (kcal/mol/Angstrom):
# [[-20.5108857   60.7467542  -10.45628536]
#  [ 23.58724937 -12.56771088  -5.32437206]
#  [ -2.65571738 -18.84936069  22.5840092 ]
#  [ 23.06017564 -35.38563513 -22.99414912]
#  [-45.54985277  31.88320596   1.62708877]]
#
# Frame:  60
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_60/output_traj.out
# Energy (a.u):  -28.659269836435946
# Energy (kcal/mol):  -17983.963188785605
#
#
# Forces (a.u):
# [[-0.03695952, 0.05049143, 0.00983904], [0.00217556, -0.01422465, -0.00105248], [0.00186398, -0.02461965, 0.00958386], [0.00990608, -0.0194981, -0.01747468], [0.02535136, 0.0204335, -0.00164333]]
# Forces (kcal/mol/Angstrom):
# [[-43.82737655  59.87380018  11.66734067]
#  [  2.57982483 -16.8678893   -1.24805293]
#  [  2.21034671 -29.19449904  11.36474286]
#  [ 11.74683812 -23.12125728 -20.72184326]
#  [ 30.06217616  24.23047428  -1.94869529]]
#
# Frame:  61
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_61/output_traj.out
# Energy (a.u):  -28.624075025800334
# Energy (kcal/mol):  -17961.878111862174
#
#
# Forces (a.u):
# [[0.009856, -0.02092864, -0.0188159], [0.00424017, 0.01005447, -0.02571256], [-0.01427795, -0.0288057, -0.01563439], [-0.01630548, 0.03154495, 0.04118633], [-0.04370363, 0.03065532, -0.05261417]]
# Forces (kcal/mol/Angstrom):
# [[ 11.6874522  -24.81762171 -22.31229016]
#  [  5.02808281  11.9228021  -30.49049472]
#  [-16.93109356 -34.15840522 -18.53958866]
#  [-19.3353813   37.40666551  48.8396168 ]
#  [-51.82468411  36.35172354 -62.39098995]]
#
# Frame:  62
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_62/output_traj.out
# Energy (a.u):  -28.65681199237048
# Energy (kcal/mol):  -17982.420868361904
#
#
# Forces (a.u):
# [[0.05877434, -0.02260839, 0.03910358], [-0.00733811, -0.00284286, 0.01799593], [0.01317684, -0.00344073, -0.01364453], [-0.02733299, 0.04745536, -0.02147084], [-0.02504508, -0.02510956, -0.05515611]]
# Forces (kcal/mol/Angstrom):
# [[ 69.69584916 -26.80950461  46.36984802]
#  [ -8.70168525  -3.37112321  21.33995248]
#  [ 15.62537415  -4.08009004 -16.1799708 ]
#  [-32.41203471  56.27356449 -25.46057388]
#  [-29.69898289 -29.77544463 -65.40527589]]
#
# Frame:  63
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_63/output_traj.out
# Energy (a.u):  -28.639928839943376
# Energy (kcal/mol):  -17971.82653035216
#
#
# Forces (a.u):
# [[-0.03682472, -0.00401802, -0.05009648], [-0.02563038, 0.00962434, 0.02549774], [-0.0135348, -0.03520279, 0.00089309], [0.00191691, 0.00820799, 0.00760001], [0.03224856, 0.01102652, 0.08575242]]
# Forces (kcal/mol/Angstrom):
# [[-43.66752788  -4.76465267 -59.40546016]
#  [-30.39304394  11.4127449   30.23575664]
#  [-16.04985065 -41.74420915   1.05904492]
#  [  2.27311222   9.73320726   9.01225178]
#  [ 38.24102105  13.07547945 101.68702412]]
#
# Frame:  64
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_64/output_traj.out
# Energy (a.u):  -28.660870949461497
# Energy (kcal/mol):  -17984.96790236962
#
#
# Forces (a.u):
# [[0.00374403, -0.0418286, 0.02504614], [-0.00085165, 0.03908698, -0.03236993], [0.01027999, 0.00187531, -0.00100961], [0.00197096, 0.01647072, 0.00853689], [0.01993896, -0.00968247, -0.04867612]]
# Forces (kcal/mol/Angstrom):
# [[  4.43974956 -49.60123408  29.70023986]
#  [ -1.00990449  46.35016339 -38.38494415]
#  [ 12.19022846   2.22378206  -1.19721678]
#  [  2.33720584  19.53132637  10.1232238 ]
#  [ 23.64403834 -11.48167667 -57.72116739]]
#
# Frame:  65
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_65/output_traj.out
# Energy (a.u):  -28.657516481526017
# Energy (kcal/mol):  -17982.86294197761
#
#
# Forces (a.u):
# [[0.03641802, 0.01219798, 0.01619086], [0.00446401, -0.01502136, 0.00905561], [-0.01885944, 0.00457992, 0.0236052], [0.00430733, 0.00253479, -0.00716602], [-0.04403378, 0.00484097, -0.02059332]]
# Forces (kcal/mol/Angstrom):
# [[ 43.18525446  14.46462137  19.19946249]
#  [  5.29351699 -17.81264478  10.7383329 ]
#  [-22.36392081   5.43096551  27.99154288]
#  [  5.10772255   3.00580732  -8.49761731]
#  [-52.21618293   5.74052409 -24.4199922 ]]
#
# Frame:  66
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_66/output_traj.out
# Energy (a.u):  -28.65121930977353
# Energy (kcal/mol):  -17978.91140707681
#
#
# Forces (a.u):
# [[-0.02637673, 0.02880466, -0.01387607], [0.00264014, 0.00448077, 0.00060664], [0.01490967, -0.00899018, 0.00123887], [0.00755433, -0.0106141, 0.00055171], [-0.02160657, -0.01060669, 0.01415937]]
# Forces (kcal/mol/Angstrom):
# [[-31.27808148  34.15717196 -16.4545358 ]
#  [  3.13073357   5.31339135   0.71936648]
#  [ 17.68020043 -10.66074462   1.46907812]
#  [  8.95808348 -12.58642313   0.65422933]
#  [-25.62152537 -12.5776362   16.7904789 ]]
#
# Frame:  67
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_67/output_traj.out
# Energy (a.u):  -28.63457513145839
# Energy (kcal/mol):  -17968.4670275851
#
#
# Forces (a.u):
# [[-0.08798521, 0.01552491, -0.0547427], [-0.01771695, 0.00336519, 0.02229002], [0.02932918, -0.02583895, 0.0084085], [0.0170131, 0.00221772, 0.02946926], [0.03199963, 0.01023739, -0.02040614]]
# Forces (kcal/mol/Angstrom):
# [[-104.33471349   18.40976497  -64.91504561]
#  [ -21.00913213    3.99051312   26.43197476]
#  [  34.77915882  -30.64037064    9.97097624]
#  [  20.17449199    2.62981904   34.94526863]
#  [  37.94583462   12.13971249  -24.19803022]]
#
# Frame:  68
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_68/output_traj.out
# Energy (a.u):  -28.65558963191647
# Energy (kcal/mol):  -17981.653825602833
#
#
# Forces (a.u):
# [[0.02349376, -0.03692891, 0.000317], [-0.02481919, 0.04406741, 0.0120502], [-0.00103719, -0.00501257, 0.00124623], [-0.00126895, 0.00097028, -0.00040501], [0.0327306, -0.02380378, -0.04113072]]
# Forces (kcal/mol/Angstrom):
# [[ 27.85939499 -43.79107857   0.37590527]
#  [-29.43111777  52.25606209  14.28938073]
#  [ -1.22992173  -5.94401099   1.47780576]
#  [ -1.50474761   1.15057844  -0.48026938]
#  [ 38.81263423 -28.22702323 -48.77367329]]
#
# Frame:  69
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_69/output_traj.out
# Energy (a.u):  -28.653647535807306
# Energy (kcal/mol):  -17980.435141905178
#
#
# Forces (a.u):
# [[-0.02627358, 0.05240939, -0.00568087], [-0.00526574, -0.0051805, 0.00220832], [0.00176086, -0.02007654, 0.00779863], [0.00129628, -0.01875938, -0.00633241], [0.06903935, -0.00944801, -0.02722361]]
# Forces (kcal/mol/Angstrom):
# [[-31.15576404  62.14815751  -6.73649519]
#  [ -6.2442253   -6.14314591   2.61867233]
#  [  2.08806484 -23.8071836    9.24777956]
#  [  1.5371561  -22.24526756  -7.50910503]
#  [ 81.86831402 -11.20364907 -32.2823296 ]]
#
# Frame:  70
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_70/output_traj.out
# Energy (a.u):  -28.653601281810744
# Energy (kcal/mol):  -17980.40611708437
#
#
# Forces (a.u):
# [[0.03189228, 0.00697355, -0.01531512], [-0.02616334, 0.03869837, 0.03046651], [-0.01841644, 0.01520886, -0.00338637], [-0.00993209, -0.02513908, 0.00172275], [-0.01444705, -0.01825099, 0.00132994]]
# Forces (kcal/mol/Angstrom):
# [[ 37.81853673   8.26938233 -18.16099157]
#  [-31.02503913  45.88934148  36.12782866]
#  [-21.83860209  18.03498623  -4.01562881]
#  [-11.77768132 -29.81045007   2.0428732 ]
#  [-17.1316159  -21.642408     1.57707084]]
#
# Frame:  71
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_71/output_traj.out
# Energy (a.u):  -28.654134749801493
# Energy (kcal/mol):  -17980.740873299823
#
#
# Forces (a.u):
# [[-0.02011418, -0.00780658, -0.04989985], [0.01007426, 0.01357717, 0.02454401], [0.0051329, -0.01142803, 0.01325017], [-0.02054591, 0.00349377, 0.00574578], [0.02784094, -0.00034552, 0.01416079]]
# Forces (kcal/mol/Angstrom):
# [[-23.85181791  -9.25720684 -59.17229217]
#  [ 11.9462695   16.10009389  29.10480354]
#  [  6.08670083 -13.55159845  15.71233041]
#  [-24.36377243   4.14298599   6.81346683]
#  [ 33.01437251  -0.40972489  16.79216277]]
#
# Frame:  72
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_72/output_traj.out
# Energy (a.u):  -28.649058102133708
# Energy (kcal/mol):  -17977.555228818965
#
#
# Forces (a.u):
# ...
# Forces (kcal/mol/Angstrom):
# [[  7.79918057 -23.9810724  -16.01839082]
#  [ 15.41310033  14.02783604  -1.61406845]
#  [-19.60974471 -35.64972934  14.02328249]
#  [-19.80942512  39.47728692  -3.43207441]
#  [ 36.02824341   7.14863915  22.44318109]]
#
# Frame:  478
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_478/output_traj.out
# Energy (a.u):  -28.66305725151403
# Energy (kcal/mol):  -17986.339827609052
#
#
# Forces (a.u):
# [[-0.01354371, -0.02850857, -0.0692414], [0.00595967, 0.01085634, -0.00228932], [-0.01013101, 0.02235526, 0.00732343], [0.03340818, -0.00626123, 0.04372114], [-0.00616646, 0.02489257, 0.01570868]]
# Forces (kcal/mol/Angstrom):
# [[-16.06041632 -33.80606221 -82.10790917]
#  [  7.0671021   12.87367642  -2.71472383]
#  [-12.01356484  26.50933773   8.6842774 ]
#  [ 39.61612285  -7.42469829  51.84544784]
#  [ -7.31231803  29.51813332  18.6276833 ]]
#
# Frame:  479
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_479/output_traj.out
# Energy (a.u):  -28.646767737511414
# Energy (kcal/mol):  -17976.118003331667
#
#
# Forces (a.u):
# [[-0.02011409, 0.01683971, -0.00277584], [0.01412512, 0.00643751, 0.01070222], [-0.01861915, 0.00386951, 0.00382279], [0.00758815, -0.01265504, 0.00332759], [-0.00035664, 0.01451713, 0.00814892]]
# Forces (kcal/mol/Angstrom):
# [[-23.85171118  19.96888248  -3.29164948]
#  [ 16.74986453   7.63373482  12.69091768]
#  [-22.07897987   4.58854638   4.53314482]
#  [  8.99818795 -15.00661273   3.94592624]
#  [ -0.42291122  17.21471824   9.66316081]]
#
# Frame:  480
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_480/output_traj.out
# Energy (a.u):  -28.652707010755158
# Energy (kcal/mol):  -17979.844953529395
#
#
# Forces (a.u):
# [[0.01320124, 0.01470953, -0.00576503], [0.00170012, -0.01701101, 0.0201132], [-0.0382615, -0.00871191, -0.01716895], [-0.00553602, -0.00083028, 0.00570221], [0.01088842, 0.03250325, -0.0347738]]
# Forces (kcal/mol/Angstrom):
# [[ 15.65430819  17.44287021  -6.83629389]
#  [  2.01603807 -20.17201362  23.8506558 ]
#  [-45.37129184 -10.3307662  -20.3593022 ]
#  [ -6.56472901  -0.9845635    6.76180061]
#  [ 12.91171756  38.54303782 -41.23550378]]
#
# Frame:  481
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_481/output_traj.out
# Energy (a.u):  -28.630017710254606
# Energy (kcal/mol):  -17965.607202626805
#
#
# Forces (a.u):
# [[0.00897651, 0.00945801, -0.01044021], [0.00970623, 0.00233834, -0.01625588], [0.0037997, 0.00837456, -0.0082588], [0.00254467, 0.00344934, -0.01185103], [-0.02258298, -0.00768881, 0.06022224]]
# Forces (kcal/mol/Angstrom):
# [[ 10.64453445  11.21550728 -12.38022071]
#  [ 11.50985178   2.77285278 -19.27656458]
#  [  4.50576422   9.93072947  -9.79345883]
#  [  3.01752323   4.09029996 -14.05320076]
#  [-26.7793729   -9.11755269  71.41279945]]
#
# Frame:  482
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_482/output_traj.out
# Energy (a.u):  -28.645195167504387
# Energy (kcal/mol):  -17975.13120076204
#
#
# Forces (a.u):
# [[-0.04150508, -0.01952885, 0.00214601], [0.00517962, -0.00926663, -0.01478079], [0.01130628, -0.00519422, -0.01837778], [0.01827919, 0.02340762, 0.04092206], [0.02867826, -0.04081217, 0.02034713]]
# Forces (kcal/mol/Angstrom):
# [[-49.21759725 -23.15772128   2.54478382]
#  [  6.14210239 -10.98856485 -17.52737181]
#  [ 13.40722474  -6.15941538 -21.79275825]
#  [ 21.67584815  27.75724836  48.52623987]
#  [ 34.00728418 -48.39593     24.12805492]]
#
# Frame:  483
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_483/output_traj.out
# Energy (a.u):  -28.65381360507932
# Energy (kcal/mol):  -17980.53935194583
#
#
# Forces (a.u):
# [[0.03781252, 0.02027229, -0.04006601], [-0.00219169, -0.02041104, 0.02014085], [-0.01058809, 0.00604169, -0.00061457], [-0.01404085, -0.00530323, 0.00407675], [0.02328053, -0.02086412, 0.05386126]]
# Forces (kcal/mol/Angstrom):
# [[ 44.8388819   24.03930807 -47.51111777]
#  [ -2.59895212 -24.20384074  23.88344375]
#  [-12.55557993   7.16436314  -0.72877004]
#  [-16.64993539  -6.28868173   4.83429594]
#  [ 27.60654237 -24.74111254  63.86981551]]
#
# Frame:  484
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_484/output_traj.out
# Energy (a.u):  -28.663936677189366
# Energy (kcal/mol):  -17986.891675547355
#
#
# Forces (a.u):
# [[-0.02953216, 0.00492769, 0.01406928], [0.00206772, 0.00475923, 0.02104118], [0.01223956, -0.00718732, -0.03328626], [0.01257166, 0.01124275, -0.00330317], [-0.01668259, 0.01077567, -0.00953908]]
# Forces (kcal/mol/Angstrom):
# [[-35.01985677   5.8433585   16.68364828]
#  [  2.45194589   5.64359508  24.95107401]
#  [ 14.5139278   -8.5228753  -39.47154755]
#  [ 14.90773897  13.33188953  -3.91696849]
#  [-19.78256627  12.77801624 -11.31164179]]
#
# Frame:  485
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_485/output_traj.out
# Energy (a.u):  -28.637913738848923
# Energy (kcal/mol):  -17970.562035334973
#
#
# Forces (a.u):
# [[0.04648881, 0.06269594, 0.03371296], [-0.02193995, 0.00021818, 0.01022036], [0.00089003, -0.00076092, 0.0207638], [-0.01449993, 0.01848831, 0.00895942], [0.03315178, -0.02312287, -0.03020104]]
# Forces (kcal/mol/Angstrom):
# [[ 55.12740916  74.34616496  39.97753739]
#  [-26.01685439   0.25872244  12.11951795]
#  [  1.0554163   -0.90231495  24.62215097]
#  [-17.19432212  21.92382705  10.62426877]
#  [ 39.31207834 -27.41958582 -35.81302875]]
#
# Frame:  486
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_486/output_traj.out
# Energy (a.u):  -28.65027411704833
# Energy (kcal/mol):  -17978.318289691986
#
#
# Forces (a.u):
# [[-0.01634334, 0.03956838, 0.02682351], [0.02922174, -0.03319447, 0.03671743], [0.02241286, 0.03022636, 0.00756947], [0.00071263, -0.00545025, -0.04400281], [-0.03341825, -0.0029063, -0.04325]]
# Forces (kcal/mol/Angstrom):
# [[-19.38027648  46.92101764  31.8078826 ]
#  [ 34.6517542  -39.36270104  43.54030114]
#  [ 26.57764102  35.84305374   8.97603681]
#  [  0.84505165  -6.46302114 -52.17945805]
#  [-39.62806407  -3.4463517  -51.28676011]]
#
# Frame:  487
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_487/output_traj.out
# Energy (a.u):  -28.63092858426709
# Energy (kcal/mol):  -17966.178784694446
#
#
# Forces (a.u):
# [[0.00104998, -0.03436535, -0.03462186], [-0.01054629, 0.0179958, 0.04170936], [0.00796275, 0.00728756, 0.01352762], [-0.00820903, 0.01497619, -0.0028033], [-0.05823396, -0.00631704, 0.01843747]]
# Forces (kcal/mol/Angstrom):
# [[  1.24508838 -40.75115518 -41.05533014]
#  [-12.50601261  21.33979833  49.45983678]
#  [  9.44239651   8.641742    16.04133646]
#  [ -9.73444052  17.75908125  -3.32421213]
#  [-69.05505518  -7.49087896  21.86353991]]
#
# Frame:  488
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_488/output_traj.out
# Energy (a.u):  -28.645980375370126
# Energy (kcal/mol):  -17975.623926132703
#
#
# Forces (a.u):
# [[0.00146754, -0.01924371, 0.04819876], [-0.00342271, -0.0298668, -0.00931422], [0.00146101, -0.0044096, -0.04786572], [-0.01601953, -0.00291199, 0.00175143], [0.02885996, 0.0230497, -0.02496057]]
# Forces (kcal/mol/Angstrom):
# [[  1.74023981 -22.81959626  57.15510385]
#  [ -4.05872154 -35.41667993 -11.04499807]
#  [  1.7324964   -5.22899647 -56.76017801]
#  [-18.99629577  -3.45309902   2.07688255]
#  [ 34.22274787  27.33281929 -29.59876915]]
#
# Frame:  489
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_489/output_traj.out
# Energy (a.u):  -28.647126896913495
# Energy (kcal/mol):  -17976.34337925725
#
#
# Forces (a.u):
# [[0.01413133, -0.0701326, -0.00104258], [-0.02687789, 0.00795465, -0.00022743], [0.01227475, 0.04656598, 0.01687816], [-0.01248794, 0.01590145, 0.00194887], [0.02869304, -0.04436826, 0.01114181]]
# Forces (kcal/mol/Angstrom):
# [[ 16.75722848 -83.16471288  -1.2363133 ]
#  [-31.87236755   9.43279136  -0.26969128]
#  [ 14.55565685  55.21891897  20.01447729]
#  [-14.80846204  18.85627402   2.31101106]
#  [ 34.02481062 -52.61281635  13.21219275]]
#
# Frame:  490
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_490/output_traj.out
# Energy (a.u):  -28.656308787787186
# Energy (kcal/mol):  -17982.105102721187
#
#
# Forces (a.u):
# [[-0.01996229, -0.00253421, -0.00745702], [0.00646657, -0.01030501, -0.02905305], [0.00798419, 0.03200717, -0.00644381], [-0.00476667, 0.00793051, 0.00252453], [0.01365591, 0.00245247, 0.01374341]]
# Forces (kcal/mol/Angstrom):
# [[-23.67170355  -3.00511955  -8.84269123]
#  [  7.66819478 -12.21989771 -34.45171805]
#  [  9.46782051  37.95477571  -7.64120549]
#  [ -5.65241759   9.40416564   2.9936408 ]
#  [ 16.19346544   2.90819053  16.29722478]]
#
# Frame:  491
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_491/output_traj.out
# Energy (a.u):  -28.64463802490416
# Energy (kcal/mol):  -17974.781588504975
#
#
# Forces (a.u):
# [[0.0494254, -0.0262445, 9.254e-05], [0.00710437, -0.01128647, 0.01505115], [-0.02408958, 0.0001647, 0.01097603], [-0.01899369, -0.00636554, -0.01836733], [0.01842168, 0.05698793, -0.00243615]]
# Forces (kcal/mol/Angstrom):
# [[ 58.60967938 -31.12128036   0.10973588]
#  [  8.42451144 -13.38373363  17.84797039]
#  [-28.56593088   0.19530473  13.01560734]
#  [-22.52311729  -7.54839128 -21.78036642]
#  [ 21.84481579  67.57748659  -2.88883793]]
#
# Frame:  492
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_492/output_traj.out
# Energy (a.u):  -28.644514469384657
# Energy (kcal/mol):  -17974.704056246577
#
#
# Forces (a.u):
# [[-0.05012027, 0.00387645, 0.0219413], [0.02120309, 0.00909442, 0.00519357], [0.02339261, 0.00300545, 0.00275228], [-0.00078882, -0.0218437, -0.0310967], [0.00171182, -0.01438653, 0.01007968]]
# Forces (kcal/mol/Angstrom):
# [[-59.43367085   4.59677598  26.01845525]
#  [ 25.1430703   10.78435461   6.15864459]
#  [ 27.73944919   3.56392585   3.26371154]
#  [ -0.93539936 -25.90271912 -36.87512123]
#  [  2.02991218 -17.05985001  11.95269665]]
#
# Frame:  493
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_493/output_traj.out
# Energy (a.u):  -28.63769710764285
# Energy (kcal/mol):  -17970.426097201944
#
#
# Forces (a.u):
# [[0.00613205, -0.05059236, 0.00736657], [-0.00409416, 0.03013949, 0.0118858], [-0.02062506, -0.00540962, -0.00740234], [0.03951813, 0.01832525, -0.04304348], [-0.03479789, 0.00694086, 0.02741744]]
# Forces (kcal/mol/Angstrom):
# [[  7.27151393 -59.9934851    8.73543372]
#  [ -4.85494108  35.74004147  14.09443175]
#  [-24.45763016  -6.41484123  -8.77785054]
#  [ 46.86143013  21.73046707 -51.04186435]
#  [-41.26407021   8.23061784  32.5121773 ]]
#
# Frame:  494
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_494/output_traj.out
# Energy (a.u):  -28.64689390457633
# Energy (kcal/mol):  -17976.197174359542
#
#
# Forces (a.u):
# [[0.0534665, 0.0518464, -0.01907933], [-0.00729988, 0.01230474, 0.00207436], [0.01377454, -0.01156108, 0.03899217], [-0.06963386, -0.03852455, 0.00154051], [0.00429244, -0.02973216, 0.03433354]]
# Forces (kcal/mol/Angstrom):
# [[ 63.40170079  61.48055212 -22.624671  ]
#  [ -8.65635132  14.59121962   2.45981974]
#  [ 16.33413939 -13.70937194  46.2377357 ]
#  [-82.57329649 -45.68322206   1.82676917]
#  [  5.09006568 -35.25702098  40.71343421]]
#
# Frame:  495
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_495/output_traj.out
# Energy (a.u):  -28.65403383025367
# Energy (kcal/mol):  -17980.677545327984
#
#
# Forces (a.u):
# [[0.04418497, -0.01195324, 0.04769116], [0.00477132, -0.00659012, -0.01104389], [-0.0025703, -0.00168773, -0.01080585], [0.00889276, 0.01364838, -0.0280929], [-0.03440227, -0.04317888, -0.02649073]]
# Forces (kcal/mol/Angstrom):
# [[ 52.39546721 -14.17440352  56.55318109]
#  [  5.65793166  -7.81470297 -13.09607716]
#  [ -3.04791583  -2.00134575 -12.81380432]
#  [ 10.54522194  16.18453621 -33.31315198]
#  [-40.79493569 -51.20242452 -31.41326508]]
#
# Frame:  496
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_496/output_traj.out
# Energy (a.u):  -28.649103763795125
# Energy (kcal/mol):  -17977.58388194386
#
#
# Forces (a.u):
# [[-0.03368872, -0.00034772, 0.03329205], [0.02585864, -0.02428523, -0.01467294], [0.00222189, -0.00229524, -0.01832614], [-0.00177688, 0.02550009, -0.00206827], [-0.00785658, -0.03460669, -0.02579544]]
# Forces (kcal/mol/Angstrom):
# [[-39.94879309  -0.41233369  39.47841345]
#  [ 30.66371945 -28.79793677 -17.39948101]
#  [  2.63476392  -2.72174389 -21.73152245]
#  [ -2.10706169  30.23854332  -2.45259809]
#  [ -9.31649789 -41.03734123 -30.58877557]]
#
# Frame:  497
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_497/output_traj.out
# Energy (a.u):  -28.65495725995981
# Energy (kcal/mol):  -17981.25700621228
#
#
# Forces (a.u):
# [[0.06652995, -0.0708236, 0.00372456], [0.00084621, 0.00897585, 0.02904768], [-0.05845667, 0.05346212, -0.04273499], [0.00236898, -0.00651271, 0.00737475], [-0.00210318, 0.04467485, -0.02231444]]
# Forces (kcal/mol/Angstrom):
# [[ 78.8926147  -83.98411522   4.41666162]
#  [  1.00345362  10.64375181  34.44535019]
#  [-69.31914939  63.3965069  -50.67605041]
#  [  2.80918633  -7.72290856   8.74513374]
#  [ -2.4939951   52.97637722 -26.46093251]]
#
# Frame:  498
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_498/output_traj.out
# Energy (a.u):  -28.655937538745068
# Energy (kcal/mol):  -17981.872140432006
#
#
# Forces (a.u):
# [[-0.02468285, 0.00843194, -0.00112596], [0.0036873, -0.03516552, -0.04311113], [-0.01176895, -0.00928512, 0.01921298], [0.02907744, 0.02691165, -0.00450855], [-0.02515823, -0.04109231, -0.00413462]]
# Forces (kcal/mol/Angstrom):
# [[-29.26944293   9.99877189  -1.33518706]
#  [  4.37247793 -41.7000136  -51.12208514]
#  [-13.95586856 -11.01049068  22.78315598]
#  [ 34.48064023  31.91240087  -5.34633346]
#  [-29.83315854 -48.7281259   -4.9029194 ]]
#
# Frame:  499
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_499/output_traj.out
# Energy (a.u):  -28.627869549792745
# Energy (kcal/mol):  -17964.259211596673
#
#
# Forces (a.u):
# [[-0.01451529, -0.03177112, -0.03527503], [0.02858531, 0.01756325, 0.05867965], [0.01220798, 0.00641353, 0.01233397], [-0.00549954, 0.01614655, 0.00467946], [-0.02593462, -0.00868991, -0.05785388]]
# Forces (kcal/mol/Angstrom):
# [[-17.21253633 -37.67486266 -41.82987287]
#  [ 33.89706212  20.82687143  69.58356376]
#  [ 14.47647958   7.60529883  14.62588117]
#  [ -6.52147026  19.14691876   5.54900214]
#  [-30.75381814 -10.30467814 -68.60434832]]
#
# Frame:  500
#
# Coordinates:
# Shape of coordinates: (14, 3)
#
#
# Extracting Energy from file:
# File path:  ./But_BoltzDist_SPC_500/output_traj.out
# Energy (a.u):  -28.644801662540452
# Energy (kcal/mol):  -17974.88427267119
#
#
# Forces (a.u):
# [[0.01243962, -0.02799863, 0.01304921], [-0.00742844, -0.01598664, 0.01526153], [0.01956973, 0.02349977, -0.01483619], [-0.00746102, 0.01170305, 0.02070971], [-0.00682874, 0.01167072, -0.05620262]]
# Forces (kcal/mol/Angstrom):
# [[ 14.75116316 -33.20136463  15.47402781]
#  [ -8.80880047 -18.95729412  18.09744342]
#  [ 23.20619764  27.86652177 -17.5930663 ]
#  [ -8.84743452  13.87772296  24.55800991]
#  [ -8.09766359  13.83938536 -66.64624947]]
#
# Shape of final arrays stored in the npz file:
#
# Energy array shape:  (500,)
# Forces array shape:  (500, 28, 3)
# Coordinates array shape:  (500, 14, 3)
# Atomic numbers array shape:  (14,)
# 0

# %% [markdown]
# Training data sets have been created sucesfully
